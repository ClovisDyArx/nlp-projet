# %% [markdown]
# # Course 2 - N-grams
#
# ## Import librairies

# %%
from datasets import load_dataset
from collections import Counter, defaultdict
import math
from nltk.tokenize import word_tokenize, sent_tokenize

# %% [markdown]
# ## Import dataset

# %%
import nltk

nltk.download('stopwords')
from nltk.corpus import stopwords

nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
dataset = load_dataset("yaful/DeepfakeTextDetect")
df = dataset["train"].to_pandas()
df.head()
# Out:
# Downloading data: 100%|██████████| 233M/233M [00:01<00:00, 185MB/s]
# Downloading data: 100%|██████████| 42.3M/42.3M [00:00<00:00, 150MB/s]
# Downloading data: 100%|██████████| 41.9M/41.9M [00:00<00:00, 84.0MB/s]
# Downloading data: 100%|██████████| 1.29M/1.29M [00:00<00:00, 9.35MB/s]
# Downloading data: 100%|██████████| 2.13M/2.13M [00:00<00:00, 23.8MB/s]
# Generating train split:   0%|          | 0/319071 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/56792 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/56819 [00:00<?, ? examples/s]
# Generating test_ood_gpt split:   0%|          | 0/1562 [00:00<?, ? examples/s]
# Generating test_ood_gpt_para split:   0%|          | 0/2362 [00:00<?, ? examples/s]
#                                                 text  label        src
# 0  White girls very rarely date Asian men. Even i...      1  cmv_human
# 1  I am a 23 year old male Indian American male. ...      1  cmv_human
# 2  Take three people, Persons A, B, and C. They l...      1  cmv_human
# 3  (A) Work part-time in high school; Then go to ...      1  cmv_human
# 4  When police introduce a new form of speed prev...      1  cmv_human

# %%
df["text"] = df["text"].astype(str)

#X_train, X_test, y_train, y_test = train_test_split(df["text"], df["label"], test_size=0.2, random_state=69)

train_df = df.query("src != 'cmv_machine_continuation_opt_iml_30b'")
train_list = list(train_df["text"])
print("Number of dream reports in the training set:",len(train_list))

test_df = df.query("src == 'cmv_machine_continuation_opt_iml_30b'")
test_list = list(test_df["text"])
print("Number of dream reports in the test set:",len(test_list))
# Out:
# Number of dream reports in the training set: 318457
# Number of dream reports in the test set: 614

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
train_strings = " ".join(train_list)
train_strings = train_strings.lower()
train_tokens = word_tokenize(train_strings)
print("Number of tokens in the training set:",len(train_tokens))

vocab = set(train_tokens)
print("Vocabulary size:",len(vocab))

test_strings = " ".join(test_list)
test_strings = test_strings.lower()
test_tokens = word_tokenize(test_strings)
print("Number of tokens in the test set:",len(test_tokens))
# Out:
# Number of tokens in the training set: 77450096
# Vocabulary size: 494023
# Number of tokens in the test set: 119560

# %% [markdown]
# ## Train n-grams

# %%
def tokenize(text):
    """Tokenize the input text."""
    
    return word_tokenize(text)

def count_ngrams(tokens, n):
    """Counts n-grams."""
    
    ngrams = [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]
    
    return Counter(ngrams)

def calculate_ngram_probabilities(train_tokens, n, test_tokens, k=0.00001):
    """Calculates n-gram probabilities."""
    
    vocab = set(train_tokens)
    V = len(vocab)
    ngram_counts = count_ngrams(train_tokens, n)
    n_minus_one_gram_counts = count_ngrams(train_tokens, n-1)
    ngram_probabilities = defaultdict(float)
    
    for ngram in ngram_counts:
        prefix = ngram[:-1]
        ngram_counts[ngram] += k
        n_minus_one_gram_counts[prefix] += k
        ngram_probabilities[ngram] = (ngram_counts[ngram] + k) / (n_minus_one_gram_counts[prefix] + k*V)

    for i in range(len(test_tokens)-n+1):
        ngram = tuple(test_tokens[i:i+n])
        if ngram not in ngram_counts:
            ngram_counts[ngram] = k
            prefix = ngram[:-1]
            if prefix not in n_minus_one_gram_counts:
                n_minus_one_gram_counts[prefix] = k
            ngram_probabilities[ngram] = (ngram_counts[ngram] + k) / (n_minus_one_gram_counts[prefix] + k*V)
    
    return ngram_probabilities

# %% [markdown]
# ## Example

# %%
n = 5

ngram_probabilities = calculate_ngram_probabilities(train_tokens, n, test_tokens)
print(f"Number of {n}-grams:",len(ngram_probabilities))
# Out:
# Number of 5-grams: 59220569

# %%
ngram_probabilities
# Out:
# defaultdict(float,
#             {('white', 'girls', 'very', 'rarely', 'date'): 0.8196667662409259,
#              ('girls', 'very', 'rarely', 'date', 'asian'): 0.8453292774255923,
#              ('very', 'rarely', 'date', 'asian', 'men'): 0.8453292774255923,
#              ('rarely', 'date', 'asian', 'men', '.'): 0.8453292774255923,
#              ('date', 'asian', 'men', '.', 'even'): 0.7660529212521773,
#              ('asian', 'men', '.', 'even', 'in'): 0.4566194311790747,
#              ('men', '.', 'even', 'in', 'asia'): 0.8403302624672595,
#              ('.', 'even', 'in', 'asia', 'white'): 0.8453292774255923,
#              ('even', 'in', 'asia', 'white', 'men'): 0.8140208088605471,
#              ('in', 'asia', 'white', 'men', 'are'): 0.8403302624672595,
#              ('asia', 'white', 'men', 'are', 'much'): 0.8403302624672595,
#              ('white', 'men', 'are', 'much', 'more'): 0.8403302624672595,
#              ('men', 'are', 'much', 'more', 'popular'): 0.7234236610551292,
#              ('are', 'much', 'more', 'popular', 'than'): 0.8453292774255923,
#              ('much', 'more', 'popular', 'than', 'asian'): 0.6852887593752701,
#              ('more', 'popular', 'than', 'asian', 'men'): 0.8140208088605471,
#              ('popular', 'than', 'asian', 'men', '.'): 0.8403302624672595,
#              ('than', 'asian', 'men', '.', 'even'): 0.8403302624672595,
#              ('asian', 'men', '.', 'even', 'though'): 0.4566193509863409,
#              ('men', '.', 'even', 'though', 'an'): 0.8140208088605471,
#              ('.', 'even', 'though', 'an', 'asian'): 0.8403302624672595,
#              ('even', 'though', 'an', 'asian', 'guy'): 0.8403302624672595,
#              ('though', 'an', 'asian', 'guy', 'may'): 0.8403302624672595,
#              ('an', 'asian', 'guy', 'may', 'have'): 0.744128260137881,
#              ('asian', 'guy', 'may', 'have', 'a'): 0.8403302624672595,
#              ('guy', 'may', 'have', 'a', 'preference'): 0.8403302624672595,
#              ('may', 'have', 'a', 'preference', 'for'): 0.8403302624672595,
#              ('have', 'a', 'preference', 'for', 'white'): 0.6676902864491846,
#              ('a', 'preference', 'for', 'white', 'girls'): 0.09392603186450697,
#              ('preference',
#               'for',
#               'white',
#               'girls',
#               'he'): 0.12594329642428945,
#              ('for', 'white', 'girls', 'he', 'does'): 0.16834673346531454,
#              ('white', 'girls', 'he', 'does', "n't"): 0.16834673346531454,
#              ('girls', 'he', 'does', "n't", 'have'): 0.16834673346531454,
#              ('he', 'does', "n't", 'have', 'much'): 0.041107198932457546,
#              ('does', "n't", 'have', 'much', 'of'): 0.05337613010046404,
#              ("n't", 'have', 'much', 'of', 'a'): 0.6839241782656867,
#              ('have', 'much', 'of', 'a', 'chance'): 0.11551775656023151,
#              ('much', 'of', 'a', 'chance', 'with'): 0.11148234360298415,
#              ('of', 'a', 'chance', 'with', 'one'): 0.14409011792099408,
#              ('a', 'chance', 'with', 'one', 'so'): 0.16834673346531454,
#              ('chance', 'with', 'one', 'so', 'he'): 0.16834673346531454,
#              ('with', 'one', 'so', 'he', 'should'): 0.16834673346531454,
#              ('one', 'so', 'he', 'should', 'instead'): 0.16834673346531454,
#              ('so', 'he', 'should', 'instead', 'pursue'): 0.16834673346531454,
#              ('he', 'should', 'instead', 'pursue', 'a'): 0.16834673346531454,
#              ('should',
#               'instead',
#               'pursue',
#               'a',
#               'non-white'): 0.16834673346531454,
#              ('instead',
#               'pursue',
#               'a',
#               'non-white',
#               'girl'): 0.16834673346531454,
#              ('pursue', 'a', 'non-white', 'girl', '.'): 0.16834673346531454,
#              ('a', 'non-white', 'girl', '.', 'asian'): 0.16834673346531454,
#              ('non-white', 'girl', '.', 'asian', 'guys'): 0.16834673346531454,
#              ('girl', '.', 'asian', 'guys', 'are'): 0.16834673346531454,
#              ('.', 'asian', 'guys', 'are', 'penalized'): 0.0837520853852184,
#              ('asian', 'guys', 'are', 'penalized', 'by'): 0.16834673346531454,
#              ('guys', 'are', 'penalized', 'by', 'their'): 0.16834673346531454,
#              ('are', 'penalized', 'by', 'their', 'looks'): 0.16834673346531454,
#              ('penalized',
#               'by',
#               'their',
#               'looks',
#               'because'): 0.16834673346531454,
#              ('by', 'their', 'looks', 'because', 'i'): 0.16834673346531454,
#              ('their', 'looks', 'because', 'i', 'do'): 0.16834673346531454,
#              ('looks', 'because', 'i', 'do', "n't"): 0.16834673346531454,
#              ('because', 'i', 'do', "n't", 'see'): 0.017351824834467046,
#              ('i', 'do', "n't", 'see', 'them'): 0.015080981375539117,
#              ('do', "n't", 'see', 'them', 'as'): 0.21983310307902443,
#              ("n't", 'see', 'them', 'as', 'being'): 0.17709430326843068,
#              ('see',
#               'them',
#               'as',
#               'being',
#               'significantly'): 0.09140750111514923,
#              ('them',
#               'as',
#               'being',
#               'significantly',
#               'less'): 0.16834673346531454,
#              ('as',
#               'being',
#               'significantly',
#               'less',
#               'social'): 0.16834673346531454,
#              ('being',
#               'significantly',
#               'less',
#               'social',
#               ','): 0.16834673346531454,
#              ('significantly',
#               'less',
#               'social',
#               ',',
#               'athletic'): 0.16834673346531454,
#              ('less', 'social', ',', 'athletic', ','): 0.16834673346531454,
#              ('social',
#               ',',
#               'athletic',
#               ',',
#               'intelligent'): 0.16834673346531454,
#              (',', 'athletic', ',', 'intelligent', ','): 0.16834673346531454,
#              ('athletic',
#               ',',
#               'intelligent',
#               ',',
#               'wealthy'): 0.16834673346531454,
#              (',', 'intelligent', ',', 'wealthy', ','): 0.16834673346531454,
#              ('intelligent', ',', 'wealthy', ',', 'etc'): 0.16834673346531454,
#              (',', 'wealthy', ',', 'etc', '.'): 0.16834673346531454,
#              ('wealthy', ',', 'etc', '.', 'facial'): 0.14409011792099408,
#              (',', 'etc', '.', 'facial', 'looks'): 0.16834673346531454,
#              ('etc', '.', 'facial', 'looks', 'are'): 0.16834673346531454,
#              ('.', 'facial', 'looks', 'are', 'genetic'): 0.16834673346531454,
#              ('facial', 'looks', 'are', 'genetic', 'and'): 0.16834673346531454,
#              ('looks', 'are', 'genetic', 'and', 'can'): 0.16834673346531454,
#              ('are', 'genetic', 'and', 'can', 'not'): 0.16834673346531454,
#              ('genetic', 'and', 'can', 'not', 'be'): 0.16834673346531454,
#              ('and', 'can', 'not', 'be', 'changed'): 0.032977971228354976,
#              ('can', 'not', 'be', 'changed', 'easily'): 0.05271500654713834,
#              ('not', 'be', 'changed', 'easily', '.'): 0.14409011792099408,
#              ('be', 'changed', 'easily', '.', 'having'): 0.14409011792099408,
#              ('changed', 'easily', '.', 'having', 'a'): 0.16834673346531454,
#              ('easily', '.', 'having', 'a', 'fit'): 0.16834673346531454,
#              ('.', 'having', 'a', 'fit', 'body'): 0.16834673346531454,
#              ('having', 'a', 'fit', 'body', 'helps'): 0.16834673346531454,
#              ('a', 'fit', 'body', 'helps', 'but'): 0.16834673346531454,
#              ('fit', 'body', 'helps', 'but', 'not'): 0.16834673346531454,
#              ('body', 'helps', 'but', 'not', 'nearly'): 0.16834673346531454,
#              ('helps', 'but', 'not', 'nearly', 'as'): 0.16834673346531454,
#              ('but', 'not', 'nearly', 'as', 'much'): 0.1624250410933984,
#              ('not', 'nearly', 'as', 'much', 'as'): 0.44592602997507275,
#              ('nearly', 'as', 'much', 'as', 'for'): 0.023843926501135905,
#              ('as', 'much', 'as', 'for', 'white'): 0.14409011792099408,
#              ('much', 'as', 'for', 'white', 'or'): 0.16834673346531454,
#              ('as', 'for', 'white', 'or', 'black'): 0.16834673346531454,
#              ('for', 'white', 'or', 'black', 'guys'): 0.16834673346531454,
#              ('white', 'or', 'black', 'guys', '.'): 0.16834673346531454,
#              ('or', 'black', 'guys', '.', 'i'): 0.16834673346531454,
#              ('black', 'guys', '.', 'i', 'wish'): 0.16834673346531454,
#              ('guys', '.', 'i', 'wish', 'it'): 0.16834673346531454,
#              ('.', 'i', 'wish', 'it', 'were'): 0.046576823976763986,
#              ('i', 'wish', 'it', 'were', "n't"): 0.20120439747933655,
#              ('wish', 'it', 'were', "n't", 'true'): 0.12594329642428945,
#              ('it', 'were', "n't", 'true', '.'): 0.14409011792099408,
#              ('were', "n't", 'true', '.', 'edit'): 0.11185605755550189,
#              ("n't", 'true', '.', 'edit', ':'): 0.28817735409726464,
#              ('true', '.', 'edit', ':', 'basically'): 0.14409011792099408,
#              ('.', 'edit', ':', 'basically', 'i'): 0.16834673346531454,
#              ('edit', ':', 'basically', 'i', "'m"): 0.16834673346531454,
#              (':', 'basically', 'i', "'m", 'saying'): 0.16834673346531454,
#              ('basically', 'i', "'m", 'saying', 'asian'): 0.14409011792099408,
#              ('i', "'m", 'saying', 'asian', 'men'): 0.16834673346531454,
#              ("'m", 'saying', 'asian', 'men', 'are'): 0.16834673346531454,
#              ('saying', 'asian', 'men', 'are', 'at'): 0.16834673346531454,
#              ('asian', 'men', 'are', 'at', 'a'): 0.16834673346531454,
#              ('men', 'are', 'at', 'a', 'significant'): 0.14409011792099408,
#              ('are',
#               'at',
#               'a',
#               'significant',
#               'disadvantage'): 0.16834673346531454,
#              ('at',
#               'a',
#               'significant',
#               'disadvantage',
#               'in'): 0.07727986497932034,
#              ('a',
#               'significant',
#               'disadvantage',
#               'in',
#               'the'): 0.16834673346531454,
#              ('significant',
#               'disadvantage',
#               'in',
#               'the',
#               'dating'): 0.16834673346531454,
#              ('disadvantage',
#               'in',
#               'the',
#               'dating',
#               'scene'): 0.16834673346531454,
#              ('in',
#               'the',
#               'dating',
#               'scene',
#               'especially'): 0.16834673346531454,
#              ('the',
#               'dating',
#               'scene',
#               'especially',
#               'if'): 0.16834673346531454,
#              ('dating',
#               'scene',
#               'especially',
#               'if',
#               'they'): 0.16834673346531454,
#              ('scene', 'especially', 'if', 'they', 'are'): 0.16834673346531454,
#              ('especially',
#               'if',
#               'they',
#               'are',
#               'attracted'): 0.01820195907407758,
#              ('if', 'they', 'are', 'attracted', 'to'): 0.16834673346531454,
#              ('they', 'are', 'attracted', 'to', 'white'): 0.04775589964584934,
#              ('are', 'attracted', 'to', 'white', 'women'): 0.16834673346531454,
#              ('attracted', 'to', 'white', 'women', ','): 0.16834673346531454,
#              ('to', 'white', 'women', ',', 'and'): 0.16834673346531454,
#              ('white', 'women', ',', 'and', 'most'): 0.12594329642428945,
#              ('women', ',', 'and', 'most', 'comments'): 0.16834673346531454,
#              (',', 'and', 'most', 'comments', 'so'): 0.16834673346531454,
#              ('and', 'most', 'comments', 'so', 'far'): 0.16834673346531454,
#              ('most', 'comments', 'so', 'far', 'seem'): 0.16834673346531454,
#              ('comments', 'so', 'far', 'seem', 'to'): 0.16834673346531454,
#              ('so', 'far', 'seem', 'to', 'be'): 0.28817735409726464,
#              ('far', 'seem', 'to', 'be', 'confirming'): 0.14409011792099408,
#              ('seem', 'to', 'be', 'confirming', 'that'): 0.16834673346531454,
#              ('to', 'be', 'confirming', 'that', 'view'): 0.16834673346531454,
#              ('be', 'confirming', 'that', 'view', '.'): 0.16834673346531454,
#              ('confirming', 'that', 'view', '.', 'hello'): 0.16834673346531454,
#              ('that', 'view', '.', 'hello', ','): 0.16834673346531454,
#              ('view', '.', 'hello', ',', 'users'): 0.9283405453766915,
#              ('.', 'hello', ',', 'users', 'of'): 0.9955611093727729,
#              ('hello', ',', 'users', 'of', 'cmv'): 0.9967877685546481,
#              (',', 'users', 'of', 'cmv', '!'): 0.9967877685546481,
#              ('users', 'of', 'cmv', '!', 'this'): 0.9967877685546481,
#              ('of', 'cmv', '!', 'this', 'is'): 0.9967877685546481,
#              ('cmv', '!', 'this', 'is', 'a'): 0.9967877685546481,
#              ('!', 'this', 'is', 'a', 'footnote'): 0.8277805011677914,
#              ('this', 'is', 'a', 'footnote', 'from'): 0.9968043913521522,
#              ('is', 'a', 'footnote', 'from', 'your'): 0.9909826915431091,
#              ('a',
#               'footnote',
#               'from',
#               'your',
#               'moderators'): 0.9967856785375078,
#              ('footnote',
#               'from',
#               'your',
#               'moderators',
#               '.'): 0.9967856785375078,
#              ('from', 'your', 'moderators', '.', 'we'): 0.9967856785375078,
#              ('your', 'moderators', '.', 'we', "'d"): 0.9967856785375078,
#              ('moderators', '.', 'we', "'d", 'just'): 0.9967856785375078,
#              ('.', 'we', "'d", 'just', 'like'): 0.9935576117970714,
#              ('we', "'d", 'just', 'like', 'to'): 0.9967877685546481,
#              ("'d", 'just', 'like', 'to', 'remind'): 0.9795901343811059,
#              ('just', 'like', 'to', 'remind', 'you'): 0.9967877685546481,
#              ('like', 'to', 'remind', 'you', 'of'): 0.9935576117970714,
#              ('to', 'remind', 'you', 'of', 'a'): 0.990348322490796,
#              ('remind', 'you', 'of', 'a', 'couple'): 0.9948471590306448,
#              ('you', 'of', 'a', 'couple', 'of'): 0.9967877685546481,
#              ('of', 'a', 'couple', 'of', 'things'): 0.9802543714111267,
#              ('a', 'couple', 'of', 'things', '.'): 0.9237568911182061,
#              ('couple', 'of', 'things', '.', 'firstly'): 0.9929094985558222,
#              ('of', 'things', '.', 'firstly', ','): 0.9967856785375078,
#              ('things', '.', 'firstly', ',', 'please'): 0.9789511323448364,
#              ('.', 'firstly', ',', 'please', 'remember'): 0.9967856785375078,
#              ('firstly', ',', 'please', 'remember', 'to'): 0.9961350351527005,
#              (',', 'please', 'remember', 'to', '['): 0.9922613853145732,
#              ('please', 'remember', 'to', '[', 'read'): 0.996783585798885,
#              ('remember', 'to', '[', 'read', 'through'): 0.996783585798885,
#              ('to', '[', 'read', 'through', 'our'): 0.996783585798885,
#              ('[', 'read', 'through', 'our', 'rules'): 0.996132518801643,
#              ('read', 'through', 'our', 'rules', ']'): 0.996132518801643,
#              ('through', 'our', 'rules', ']', '.'): 0.9967814903334609,
#              ('our', 'rules', ']', '.', 'if'): 0.9916132720733242,
#              ('rules', ']', '.', 'if', 'you'): 0.9967814903334609,
#              (']', '.', 'if', 'you', 'see'): 0.9776873860780282,
#              ('.', 'if', 'you', 'see', 'a'): 0.9318242620509491,
#              ('if', 'you', 'see', 'a', 'comment'): 0.9387598776288524,
#              ('you', 'see', 'a', 'comment', 'that'): 0.9967877685546481,
#              ('see', 'a', 'comment', 'that', 'has'): 0.9967877685546481,
#              ('a', 'comment', 'that', 'has', 'broken'): 0.9967877685546481,
#              ('comment', 'that', 'has', 'broken', 'one'): 0.9967877685546481,
#              ('that', 'has', 'broken', 'one', ','): 0.9967877685546481,
#              ('has', 'broken', 'one', ',', 'it'): 0.9967877685546481,
#              ('broken', 'one', ',', 'it', 'is'): 0.9967877685546481,
#              ('one', ',', 'it', 'is', 'more'): 0.9871679621347601,
#              (',', 'it', 'is', 'more', 'effective'): 0.925289520977561,
#              ('it', 'is', 'more', 'effective', 'to'): 0.9942094779523332,
#              ('is', 'more', 'effective', 'to', 'report'): 0.9954931887486751,
#              ('more', 'effective', 'to', 'report', 'it'): 0.9967877685546481,
#              ('effective', 'to', 'report', 'it', 'than'): 0.9967877685546481,
#              ('to', 'report', 'it', 'than', 'downvote'): 0.9285146346128508,
#              ('report', 'it', 'than', 'downvote', 'it'): 0.9965523893724976,
#              ('it', 'than', 'downvote', 'it', '.'): 0.9965523893724976,
#              ('than', 'downvote', 'it', '.', 'speaking'): 0.9965523893724976,
#              ('downvote', 'it', '.', 'speaking', 'of'): 0.9967877685546481,
#              ('it', '.', 'speaking', 'of', 'which'): 0.9967898558556114,
#              ('.', 'speaking', 'of', 'which', ','): 0.9942281698356549,
#              ('speaking', 'of', 'which', ',', '['): 0.9852373859627961,
#              ('of', 'which', ',', '[', 'downvotes'): 0.996783585798885,
#              ('which', ',', '[', 'downvotes', 'do'): 0.996783585798885,
#              (',', '[', 'downvotes', 'do', "n't"): 0.996783585798885,
#              ('[', 'downvotes', 'do', "n't", 'change'): 0.996783585798885,
#              ('downvotes', 'do', "n't", 'change', 'views'): 0.9967961015142844,
#              ('do', "n't", 'change', 'views', ']'): 0.9922613853145732,
#              ("n't", 'change', 'views', ']', '!'): 0.996783585798885,
#              ('change', 'views', ']', '!', 'if'): 0.996783585798885,
#              ('views', ']', '!', 'if', 'you'): 0.996783585798885,
#              (']', '!', 'if', 'you', 'are'): 0.996783585798885,
#              ('!', 'if', 'you', 'are', 'thinking'): 0.9214016104203113,
#              ('if', 'you', 'are', 'thinking', 'about'): 0.9823714362883487,
#              ('you',
#               'are',
#               'thinking',
#               'about',
#               'submitting'): 0.961164551218546,
#              ('are',
#               'thinking',
#               'about',
#               'submitting',
#               'a'): 0.9967877685546481,
#              ('thinking',
#               'about',
#               'submitting',
#               'a',
#               'cmv'): 0.9967877685546481,
#              ('about',
#               'submitting',
#               'a',
#               'cmv',
#               'yourself'): 0.9967877685546481,
#              ('submitting', 'a', 'cmv', 'yourself', ','): 0.9967877685546481,
#              ('a', 'cmv', 'yourself', ',', 'please'): 0.9967877685546481,
#              ('cmv', 'yourself', ',', 'please', 'have'): 0.9967877685546481,
#              ('yourself', ',', 'please', 'have', 'a'): 0.9967877685546481,
#              (',', 'please', 'have', 'a', 'look'): 0.9967877685546481,
#              ('please', 'have', 'a', 'look', 'through'): 0.9967877685546481,
#              ('have', 'a', 'look', 'through', 'our'): 0.9903420832856479,
#              ('a', 'look', 'through', 'our', '['): 0.9961350351527005,
#              ('look', 'through', 'our', '[', 'popular'): 0.996783585798885,
#              ('through', 'our', '[', 'popular', 'topics'): 0.996783585798885,
#              ('our', '[', 'popular', 'topics', 'wiki'): 0.996783585798885,
#              ('[', 'popular', 'topics', 'wiki', ']'): 0.996783585798885,
#              ('popular', 'topics', 'wiki', ']', 'first'): 0.996783585798885,
#              ('topics', 'wiki', ']', 'first', '.'): 0.996783585798885,
#              ('wiki', ']', 'first', '.', 'any'): 0.996783585798885,
#              (']', 'first', '.', 'any', 'questions'): 0.996783585798885,
#              ('first', '.', 'any', 'questions', 'or'): 0.9967856785375078,
#              ('.', 'any', 'questions', 'or', 'concerns'): 0.9967877685546481,
#              ('any', 'questions', 'or', 'concerns', '?'): 0.9599858502843636,
#              ('questions', 'or', 'concerns', '?', 'feel'): 0.9948471590306448,
#              ('or', 'concerns', '?', 'feel', 'free'): 0.9967877685546481,
#              ('concerns', '?', 'feel', 'free', 'to'): 0.996137548231393,
#              ('?', 'feel', 'free', 'to', '['): 0.984603768438072,
#              ('feel', 'free', 'to', '[', 'message'): 0.9968002518024921,
#              ('free', 'to', '[', 'message', 'us'): 0.9968002518024921,
#              ('to', '[', 'message', 'us', ']'): 0.9968002518024921,
#              ('[', 'message', 'us', ']', '.'): 0.9916187041021743,
#              ('message', 'us', ']', '.', 'happy'): 0.996783585798885,
#              ('us', ']', '.', 'happy', 'cmving'): 0.996783585798885,
#              (']', '.', 'happy', 'cmving', '!'): 0.996783585798885,
#              ('.', 'happy', 'cmving', '!', 'i'): 0.3090556207962907,
#              ('happy', 'cmving', '!', 'i', 'am'): 0.07084219485325925,
#              ('cmving', '!', 'i', 'am', 'a'): 0.25680427239277415,
#              ('!', 'i', 'am', 'a', '23'): 0.016537258401339374,
#              ('i', 'am', 'a', '23', 'year'): 0.8500247721328077,
#              ('am', 'a', '23', 'year', 'old'): 0.8500247721328077,
#              ('a', '23', 'year', 'old', 'male'): 0.5877204820871637,
#              ('23', 'year', 'old', 'male', 'indian'): 0.8453292774255923,
#              ('year', 'old', 'male', 'indian', 'american'): 0.8453292774255923,
#              ('old', 'male', 'indian', 'american', 'male'): 0.8453292774255923,
#              ('male', 'indian', 'american', 'male', '.'): 0.8453292774255923,
#              ('indian', 'american', 'male', '.', 'i'): 0.8453292774255923,
#              ('american', 'male', '.', 'i', 'have'): 0.8453292774255923,
#              ('male', '.', 'i', 'have', 'never'): 0.7727485558198798,
#              ('.', 'i', 'have', 'never', 'held'): 0.02687824489704824,
#              ('i', 'have', 'never', 'held', 'hands'): 0.8013688515018785,
#              ('have', 'never', 'held', 'hands', 'with'): 0.8544435749423103,
#              ('never', 'held', 'hands', 'with', 'a'): 0.824980023712266,
#              ('held', 'hands', 'with', 'a', 'girl'): 0.858609442865876,
#              ('hands', 'with', 'a', 'girl', ','): 0.8068955577369543,
#              ('with', 'a', 'girl', ',', 'been'): 0.6437736169368605,
#              ('a', 'girl', ',', 'been', 'kissed'): 0.8453292774255923,
#              ('girl', ',', 'been', 'kissed', ','): 0.8453292774255923,
#              (',', 'been', 'kissed', ',', 'or'): 0.8453292774255923,
#              ('been', 'kissed', ',', 'or', 'obviously'): 0.8196667662409259,
#              ('kissed', ',', 'or', 'obviously', 'had'): 0.8453292774255923,
#              (',', 'or', 'obviously', 'had', 'sex'): 0.8453292774255923,
#              ('or', 'obviously', 'had', 'sex', '.'): 0.8453292774255923,
#              ('obviously', 'had', 'sex', '.', 'i'): 0.8453292774255923,
#              ('had', 'sex', '.', 'i', 'have'): 0.7116459990764422,
#              ('sex', '.', 'i', 'have', 'never'): 0.6594983322032308,
#              ('.', 'i', 'have', 'never', 'even'): 0.03151242156365935,
#              ('i', 'have', 'never', 'even', 'asked'): 0.6257795121593049,
#              ('have', 'never', 'even', 'asked', 'someone'): 0.858609442865876,
#              ('never', 'even', 'asked', 'someone', 'out'): 0.42930500763589485,
#              ('even', 'asked', 'someone', 'out', '.'): 0.1003006984870794,
#              ('asked', 'someone', 'out', '.', 'i'): 0.28817735409726464,
#              ('someone', 'out', '.', 'i', 'do'): 0.14409011792099408,
#              ('out', '.', 'i', 'do', 'not'): 0.08938145420899157,
#              ('.', 'i', 'do', 'not', 'think'): 0.1016175090629657,
#              ('i', 'do', 'not', 'think', 'a'): 0.008131452399987598,
#              ('do', 'not', 'think', 'a', 'girl'): 0.12594329642428945,
#              ('not', 'think', 'a', 'girl', 'has'): 0.16834673346531454,
#              ('think', 'a', 'girl', 'has', 'expressed'): 0.16834673346531454,
#              ('a', 'girl', 'has', 'expressed', 'even'): 0.16834673346531454,
#              ('girl', 'has', 'expressed', 'even', 'the'): 0.16834673346531454,
#              ('has',
#               'expressed',
#               'even',
#               'the',
#               'slightest'): 0.16834673346531454,
#              ('expressed',
#               'even',
#               'the',
#               'slightest',
#               'interest'): 0.16834673346531454,
#              ('even',
#               'the',
#               'slightest',
#               'interest',
#               'in'): 0.16834673346531454,
#              ('the', 'slightest', 'interest', 'in', 'me'): 0.12594329642428945,
#              ('slightest', 'interest', 'in', 'me', '.'): 0.16834673346531454,
#              ('interest', 'in', 'me', '.', 'i'): 0.2509385053173603,
#              ('in', 'me', '.', 'i', 'graduated'): 0.027071291361398846,
#              ('me', '.', 'i', 'graduated', 'from'): 0.16834673346531454,
#              ('.', 'i', 'graduated', 'from', 'college'): 0.2869405404784996,
#              ('i',
#               'graduated',
#               'from',
#               'college',
#               'last'): 0.07173621114127161,
#              ('graduated',
#               'from',
#               'college',
#               'last',
#               'year'): 0.28817735409726464,
#              ('from', 'college', 'last', 'year', 'and'): 0.14409011792099408,
#              ('college', 'last', 'year', 'and', 'am'): 0.16834673346531454,
#              ('last', 'year', 'and', 'am', 'about'): 0.16834673346531454,
#              ('year', 'and', 'am', 'about', 'to'): 0.16834673346531454,
#              ('and', 'am', 'about', 'to', 'start'): 0.12594329642428945,
#              ('am', 'about', 'to', 'start', 'med'): 0.14409011792099408,
#              ('about', 'to', 'start', 'med', 'school'): 0.16834673346531454,
#              ('to', 'start', 'med', 'school', 'in'): 0.16834673346531454,
#              ('start', 'med', 'school', 'in', 'a'): 0.16834673346531454,
#              ('med', 'school', 'in', 'a', 'month'): 0.16834673346531454,
#              ('school', 'in', 'a', 'month', '.'): 0.16834673346531454,
#              ('in', 'a', 'month', '.', 'i'): 0.14310205081590735,
#              ('a', 'month', '.', 'i', 'had'): 0.04004826568714928,
#              ('month', '.', 'i', 'had', 'been'): 0.14409011792099408,
#              ('.', 'i', 'had', 'been', 'fat'): 0.00113905247127071,
#              ('i', 'had', 'been', 'fat', 'for'): 0.16834673346531454,
#              ('had', 'been', 'fat', 'for', 'years'): 0.16834673346531454,
#              ('been', 'fat', 'for', 'years', 'but'): 0.16834673346531454,
#              ('fat', 'for', 'years', 'but', 'lost'): 0.16834673346531454,
#              ('for', 'years', 'but', 'lost', 'all'): 0.16834673346531454,
#              ('years', 'but', 'lost', 'all', 'the'): 0.16834673346531454,
#              ('but', 'lost', 'all', 'the', 'weight'): 0.16834673346531454,
#              ('lost', 'all', 'the', 'weight', 'over'): 0.16834673346531454,
#              ('all', 'the', 'weight', 'over', 'the'): 0.16834673346531454,
#              ('the', 'weight', 'over', 'the', 'past'): 0.16834673346531454,
#              ('weight', 'over', 'the', 'past', 'year'): 0.2518840740330267,
#              ('over', 'the', 'past', 'year', 'and'): 0.0928121982317852,
#              ('the', 'past', 'year', 'and', 'am'): 0.020433491948547863,
#              ('past', 'year', 'and', 'am', 'pretty'): 0.16834673346531454,
#              ('year', 'and', 'am', 'pretty', 'fit'): 0.16834673346531454,
#              ('and', 'am', 'pretty', 'fit', 'now'): 0.16834673346531454,
#              ('am', 'pretty', 'fit', 'now', '.'): 0.16834673346531454,
#              ('pretty', 'fit', 'now', '.', 'i'): 0.16834673346531454,
#              ('fit', 'now', '.', 'i', 'am'): 0.16834673346531454,
#              ('now', '.', 'i', 'am', 'only'): 0.020024333082900685,
#              ('.', 'i', 'am', 'only', '5ft'): 0.023843926501135905,
#              ('i', 'am', 'only', '5ft', '4'): 0.16834673346531454,
#              ('am', 'only', '5ft', '4', 'tall'): 0.16834673346531454,
#              ('only', '5ft', '4', 'tall', 'however'): 0.16834673346531454,
#              ('5ft', '4', 'tall', 'however', '.'): 0.16834673346531454,
#              ('4', 'tall', 'however', '.', 'i'): 0.16834673346531454,
#              ('tall', 'however', '.', 'i', 'do'): 0.16834673346531454,
#              ('however', '.', 'i', 'do', 'think'): 0.12594329642428945,
#              ('.', 'i', 'do', 'think', 'facially'): 0.009907049953517053,
#              ('i', 'do', 'think', 'facially', 'i'): 0.16834673346531454,
#              ('do', 'think', 'facially', 'i', 'am'): 0.16834673346531454,
#              ('think', 'facially', 'i', 'am', 'slight'): 0.16834673346531454,
#              ('facially', 'i', 'am', 'slight', 'above'): 0.16834673346531454,
#              ('i', 'am', 'slight', 'above', 'average'): 0.16834673346531454,
#              ('am', 'slight', 'above', 'average', 'and'): 0.16834673346531454,
#              ('slight', 'above', 'average', 'and', 'i'): 0.16834673346531454,
#              ('above', 'average', 'and', 'i', 'would'): 0.14409011792099408,
#              ('average', 'and', 'i', 'would', "n't"): 0.14409011792099408,
#              ('and', 'i', 'would', "n't", 'call'): 0.009714568374816303,
#              ('i', 'would', "n't", 'call', 'myself'): 0.13912038428235313,
#              ('would', "n't", 'call', 'myself', 'ugly'): 0.10060320475159555,
#              ("n't", 'call', 'myself', 'ugly', '.'): 0.16834673346531454,
#              ('call', 'myself', 'ugly', '.', 'my'): 0.16834673346531454,
#              ('myself', 'ugly', '.', 'my', 'family'): 0.16834673346531454,
#              ('ugly', '.', 'my', 'family', 'struggled'): 0.16834673346531454,
#              ('.',
#               'my',
#               'family',
#               'struggled',
#               'financially'): 0.16834673346531454,
#              ('my',
#               'family',
#               'struggled',
#               'financially',
#               'and'): 0.16834673346531454,
#              ('family',
#               'struggled',
#               'financially',
#               'and',
#               'i'): 0.14409011792099408,
#              ('struggled',
#               'financially',
#               'and',
#               'i',
#               'focused'): 0.16834673346531454,
#              ('financially', 'and', 'i', 'focused', 'on'): 0.16834673346531454,
#              ('and', 'i', 'focused', 'on', 'academics'): 0.14409011792099408,
#              ('i', 'focused', 'on', 'academics', 'like'): 0.16834673346531454,
#              ('focused', 'on', 'academics', 'like', 'a'): 0.16834673346531454,
#              ('on', 'academics', 'like', 'a', 'madman'): 0.16834673346531454,
#              ('academics', 'like', 'a', 'madman', 'and'): 0.16834673346531454,
#              ('like', 'a', 'madman', 'and', 'was'): 0.12594329642428945,
#              ('a', 'madman', 'and', 'was', 'able'): 0.16834673346531454,
#              ('madman', 'and', 'was', 'able', 'to'): 0.16834673346531454,
#              ('and', 'was', 'able', 'to', 'go'): 0.022129833977338427,
#              ('was', 'able', 'to', 'go', 'to'): 0.233566298700172,
#              ('able', 'to', 'go', 'to', 'a'): 0.06477619442718681,
#              ('to', 'go', 'to', 'a', 'great'): 0.004815903368194676,
#              ('go', 'to', 'a', 'great', 'college'): 0.2237098780345942,
#              ('to', 'a', 'great', 'college', 'and'): 0.14409011792099408,
#              ('a', 'great', 'college', 'and', 'am'): 0.16834673346531454,
#              ('great', 'college', 'and', 'am', 'headed'): 0.16834673346531454,
#              ('college', 'and', 'am', 'headed', 'to'): 0.16834673346531454,
#              ('and', 'am', 'headed', 'to', 'a'): 0.16834673346531454,
#              ('am', 'headed', 'to', 'a', 'great'): 0.16834673346531454,
#              ('headed', 'to', 'a', 'great', 'med'): 0.16834673346531454,
#              ('to', 'a', 'great', 'med', 'school'): 0.16834673346531454,
#              ('a', 'great', 'med', 'school', '.'): 0.16834673346531454,
#              ('great', 'med', 'school', '.', 'it'): 0.16834673346531454,
#              ('med', 'school', '.', 'it', 'is'): 0.14409011792099408,
#              ('school', '.', 'it', 'is', 'my'): 0.03232101625585322,
#              ('.', 'it', 'is', 'my', 'ticket'): 0.005103698964541434,
#              ('it', 'is', 'my', 'ticket', 'to'): 0.16834673346531454,
#              ('is', 'my', 'ticket', 'to', 'a'): 0.16834673346531454,
#              ('my', 'ticket', 'to', 'a', 'better'): 0.16834673346531454,
#              ('ticket', 'to', 'a', 'better', 'life'): 0.28817735409726464,
#              ('to', 'a', 'better', 'life', '.'): 0.3656245201202167,
#              ('a', 'better', 'life', '.', 'yet'): 0.012057114857637259,
#              ('better', 'life', '.', 'yet', 'i'): 0.16834673346531454,
#              ('life', '.', 'yet', 'i', 'believe'): 0.12594329642428945,
#              ('.', 'yet', 'i', 'believe', 'strongly'): 0.16834673346531454,
#              ('yet', 'i', 'believe', 'strongly', 'that'): 0.16834673346531454,
#              ('i', 'believe', 'strongly', 'that', 'life'): 0.09140750111514923,
#              ('believe',
#               'strongly',
#               'that',
#               'life',
#               'will'): 0.16834673346531454,
#              ('strongly', 'that', 'life', 'will', 'be'): 0.16834673346531454,
#              ('that', 'life', 'will', 'be', 'one'): 0.14409011792099408,
#              ('life', 'will', 'be', 'one', 'of'): 0.16834673346531454,
#              ('will', 'be', 'one', 'of', 'loneliness'): 0.01137158597702258,
#              ('be', 'one', 'of', 'loneliness', '.'): 0.16834673346531454,
#              ('one',
#               'of',
#               'loneliness',
#               '.',
#               'internally'): 0.16834673346531454,
#              ('of', 'loneliness', '.', 'internally', 'i'): 0.16834673346531454,
#              ('loneliness', '.', 'internally', 'i', 'am'): 0.16834673346531454,
#              ('.', 'internally', 'i', 'am', 'angry'): 0.16834673346531454,
#              ('internally', 'i', 'am', 'angry', 'and'): 0.16834673346531454,
#              ('i', 'am', 'angry', 'and', 'bitter'): 0.16834673346531454,
#              ('am', 'angry', 'and', 'bitter', 'even'): 0.16834673346531454,
#              ('angry', 'and', 'bitter', 'even', 'as'): 0.16834673346531454,
#              ('and', 'bitter', 'even', 'as', 'all'): 0.16834673346531454,
#              ('bitter', 'even', 'as', 'all', 'my'): 0.16834673346531454,
#              ('even', 'as', 'all', 'my', 'friends'): 0.16834673346531454,
#              ('as', 'all', 'my', 'friends', 'think'): 0.12594329642428945,
#              ('all', 'my', 'friends', 'think', 'i'): 0.16834673346531454,
#              ('my', 'friends', 'think', 'i', 'must'): 0.11185605755550189,
#              ('friends', 'think', 'i', 'must', 'be'): 0.16834673346531454,
#              ('think', 'i', 'must', 'be', 'so'): 0.10060320475159555,
#              ('i', 'must', 'be', 'so', 'happy'): 0.16834673346531454,
#              ('must', 'be', 'so', 'happy', 'to'): 0.12594329642428945,
#              ('be', 'so', 'happy', 'to', 'start'): 0.07727986497932034,
#              ('so', 'happy', 'to', 'start', 'this'): 0.16834673346531454,
#              ('happy', 'to', 'start', 'this', 'next'): 0.16834673346531454,
#              ('to', 'start', 'this', 'next', 'chapter'): 0.16834673346531454,
#              ('start', 'this', 'next', 'chapter', 'of'): 0.16834673346531454,
#              ('this', 'next', 'chapter', 'of', 'my'): 0.28817735409726464,
#              ('next', 'chapter', 'of', 'my', 'life'): 0.3656245201202167,
#              ('chapter', 'of', 'my', 'life', '.'): 0.2512529061392401,
#              ('of', 'my', 'life', '.', 'hello'): 0.001953392059979501,
#              ('my', 'life', '.', 'hello', ','): 0.16834673346531454,
#              ('life', '.', 'hello', ',', 'users'): 0.28817735409726464,
#              ('.', 'happy', 'cmving', '!', 'take'): 0.001301299774015288,
#              ('happy', 'cmving', '!', 'take', 'three'): 0.14409011792099408,
#              ('cmving', '!', 'take', 'three', 'people'): 0.16834673346531454,
#              ('!', 'take', 'three', 'people', ','): 0.5030079756625594,
#              ('take', 'three', 'people', ',', 'persons'): 0.9066830826607511,
#              ('three', 'people', ',', 'persons', 'a'): 0.9066830826607511,
#              ('people', ',', 'persons', 'a', ','): 0.9066830826607511,
#              (',', 'persons', 'a', ',', 'b'): 0.9084130882621213,
#              ('persons', 'a', ',', 'b', ','): 0.9227369180972734,
#              ('a', ',', 'b', ',', 'and'): 0.404877216487892,
#              (',', 'b', ',', 'and', 'c.'): 0.5764616233327214,
#              ('b', ',', 'and', 'c.', 'they'): 0.8313508733591856,
#              (',', 'and', 'c.', 'they', 'live'): 0.9084130882621213,
#              ('and', 'c.', 'they', 'live', 'in'): 0.9084130882621213,
#              ('c.', 'they', 'live', 'in', 'the'): 0.9084130882621213,
#              ('they', 'live', 'in', 'the', 'us'): 0.3558475533542849,
#              ('live', 'in', 'the', 'us', '.'): 0.6670821336281836,
#              ('in', 'the', 'us', '.', 'person'): 0.07253048036472329,
#              ('the', 'us', '.', 'person', 'a'): 0.8974767795231777,
#              ('us', '.', 'person', 'a', 'was'): 0.895676238807564,
#              ('.', 'person', 'a', 'was', 'born'): 0.9132385111127035,
#              ('person', 'a', 'was', 'born', 'here'): 0.9147359417220227,
#              ('a', 'was', 'born', 'here', 'and'): 0.9147359417220227,
#              ('was', 'born', 'here', 'and', 'is'): 0.8420689212497443,
#              ('born', 'here', 'and', 'is', 'a'): 0.9147359417220227,
#              ('here', 'and', 'is', 'a', 'citizen'): 0.9147359417220227,
#              ('and', 'is', 'a', 'citizen', '.'): 0.9008976273701941,
#              ('is', 'a', 'citizen', '.', 'they'): 0.8233745946092557,
#              ('a', 'citizen', '.', 'they', 'happen'): 0.8313508733591856,
#              ('citizen', '.', 'they', 'happen', 'to'): 0.9084130882621213,
#              ('.', 'they', 'happen', 'to', 'be'): 0.8605516941972848,
#              ('they', 'happen', 'to', 'be', 'a'): 0.6053851582352611,
#              ('happen', 'to', 'be', 'a', 'huge'): 0.7785165738166872,
#              ('to', 'be', 'a', 'huge', 'idiot'): 0.47142492647698336,
#              ('be', 'a', 'huge', 'idiot', 'and'): 0.9084130882621213,
#              ('a', 'huge', 'idiot', 'and', 'do'): 0.017562623550585667,
#              ('huge', 'idiot', 'and', 'do', "n't"): 0.16834673346531454,
#              ('idiot', 'and', 'do', "n't", 'even'): 0.14409011792099408,
#              ('and', 'do', "n't", 'even', 'know'): 0.10883748104058662,
#              ('do', "n't", 'even', 'know', 'what'): 0.25052266515674515,
#              ("n't", 'even', 'know', 'what', 'the'): 0.12625031416880936,
#              ('even',
#               'know',
#               'what',
#               'the',
#               'president'): 0.030358613051999623,
#              ('know', 'what', 'the', 'president', 'does'): 0.14409011792099408,
#              ('what', 'the', 'president', 'does', '.'): 0.16834673346531454,
#              ('the', 'president', 'does', '.', 'they'): 0.16834673346531454,
#              ('president', 'does', '.', 'they', 'have'): 0.16834673346531454,
#              ('does', '.', 'they', 'have', 'the'): 0.16834673346531454,
#              ('.', 'they', 'have', 'the', 'right'): 0.057012575500061564,
#              ('they', 'have', 'the', 'right', 'to'): 0.760068882486296,
#              ('have', 'the', 'right', 'to', 'vote'): 0.04395895273298388,
#              ('the', 'right', 'to', 'vote', 'with'): 0.008003986545887859,
#              ('right', 'to', 'vote', 'with', 'literally'): 0.16834673346531454,
#              ('to', 'vote', 'with', 'literally', 'no'): 0.16834673346531454,
#              ('vote',
#               'with',
#               'literally',
#               'no',
#               'requirements'): 0.16834673346531454,
#              ('with',
#               'literally',
#               'no',
#               'requirements',
#               'other'): 0.16834673346531454,
#              ('literally',
#               'no',
#               'requirements',
#               'other',
#               'than'): 0.16834673346531454,
#              ('no',
#               'requirements',
#               'other',
#               'than',
#               'surviving'): 0.16834673346531454,
#              ('requirements',
#               'other',
#               'than',
#               'surviving',
#               'for'): 0.16834673346531454,
#              ('other', 'than', 'surviving', 'for', '18'): 0.16834673346531454,
#              ('than', 'surviving', 'for', '18', 'years'): 0.16834673346531454,
#              ('surviving', 'for', '18', 'years', 'and'): 0.16834673346531454,
#              ('for', '18', 'years', 'and', 'registering'): 0.0837520853852184,
#              ('18', 'years', 'and', 'registering', '.'): 0.16834673346531454,
#              ('years', 'and', 'registering', '.', 'they'): 0.16834673346531454,
#              ('and', 'registering', '.', 'they', 'can'): 0.16834673346531454,
#              ('registering', '.', 'they', 'can', 'vote'): 0.16834673346531454,
#              ('.', 'they', 'can', 'vote', '.'): 0.16834673346531454,
#              ('they', 'can', 'vote', '.', 'person'): 0.28817735409726464,
#              ('can', 'vote', '.', 'person', 'b'): 0.14409011792099408,
#              ('vote', '.', 'person', 'b', 'is'): 0.16834673346531454,
#              ('.', 'person', 'b', 'is', 'basically'): 0.05903222150335533,
#              ('person', 'b', 'is', 'basically', 'albert'): 0.16834673346531454,
#              ('b',
#               'is',
#               'basically',
#               'albert',
#               'freaking'): 0.16834673346531454,
#              ('is',
#               'basically',
#               'albert',
#               'freaking',
#               'einstein'): 0.16834673346531454,
#              ('basically',
#               'albert',
#               'freaking',
#               'einstein',
#               '.'): 0.16834673346531454,
#              ('albert',
#               'freaking',
#               'einstein',
#               '.',
#               'they'): 0.16834673346531454,
#              ('freaking',
#               'einstein',
#               '.',
#               'they',
#               'have'): 0.16834673346531454,
#              ('einstein', '.', 'they', 'have', 'the'): 0.14409011792099408,
#              ('.', 'they', 'have', 'the', 'highest'): 0.010366007092869424,
#              ('they', 'have', 'the', 'highest', 'known'): 0.12594329642428945,
#              ('have', 'the', 'highest', 'known', 'iq'): 0.16834673346531454,
#              ('the', 'highest', 'known', 'iq', 'in'): 0.16834673346531454,
#              ('highest', 'known', 'iq', 'in', 'the'): 0.16834673346531454,
#              ('known', 'iq', 'in', 'the', 'world'): 0.16834673346531454,
#              ('iq', 'in', 'the', 'world', '.'): 0.16834673346531454,
#              ('in', 'the', 'world', '.', 'they'): 0.01933971625360327,
#              ('the', 'world', '.', 'they', 'know'): 0.005264919113506438,
#              ('world', '.', 'they', 'know', 'every'): 0.16834673346531454,
#              ('.', 'they', 'know', 'every', 'position'): 0.16834673346531454,
#              ('they', 'know', 'every', 'position', 'of'): 0.16834673346531454,
#              ('know', 'every', 'position', 'of', 'all'): 0.16834673346531454,
#              ('every', 'position', 'of', 'all', 'the'): 0.16834673346531454,
#              ('position',
#               'of',
#               'all',
#               'the',
#               'candidates'): 0.16834673346531454,
#              ('of', 'all', 'the', 'candidates', 'and'): 0.14409011792099408,
#              ('all', 'the', 'candidates', 'and', 'can'): 0.14409011792099408,
#              ('the', 'candidates', 'and', 'can', 'vote'): 0.16834673346531454,
#              ('candidates', 'and', 'can', 'vote', 'with'): 0.16834673346531454,
#              ('and', 'can', 'vote', 'with', 'the'): 0.16834673346531454,
#              ('can', 'vote', 'with', 'the', 'utmost'): 0.16834673346531454,
#              ('vote',
#               'with',
#               'the',
#               'utmost',
#               'qualification'): 0.16834673346531454,
#              ('with',
#               'the',
#               'utmost',
#               'qualification',
#               '.'): 0.16834673346531454,
#              ('the',
#               'utmost',
#               'qualification',
#               '.',
#               'before'): 0.16834673346531454,
#              ('utmost',
#               'qualification',
#               '.',
#               'before',
#               'they'): 0.16834673346531454,
#              ('qualification',
#               '.',
#               'before',
#               'they',
#               'do'): 0.16834673346531454,
#              ('.', 'before', 'they', 'do', 'this'): 0.14409011792099408,
#              ('before', 'they', 'do', 'this', ','): 0.16834673346531454,
#              ('they', 'do', 'this', ',', 'they'): 0.2787041867890284,
#              ('do', 'this', ',', 'they', 'must'): 0.02704914130654702,
#              ('this', ',', 'they', 'must', 'pass'): 0.14409011792099408,
#              (',', 'they', 'must', 'pass', 'a'): 0.16834673346531454,
#              ('they', 'must', 'pass', 'a', 'citizenship'): 0.16834673346531454,
#              ('must', 'pass', 'a', 'citizenship', 'test'): 0.16834673346531454,
#              ('pass', 'a', 'citizenship', 'test', '.'): 0.0837520853852184,
#              ('a', 'citizenship', 'test', '.', 'they'): 0.16834673346531454,
#              ('citizenship', 'test', '.', 'they', 'do'): 0.16834673346531454,
#              ('test', '.', 'they', 'do', ','): 0.16834673346531454,
#              ('.', 'they', 'do', ',', 'and'): 0.10559633880035312,
#              ('they', 'do', ',', 'and', 'they'): 0.17678189665129057,
#              ('do', ',', 'and', 'they', 'can'): 0.10020026559573338,
#              (',', 'and', 'they', 'can', 'vote'): 0.0037745115653250723,
#              ('and', 'they', 'can', 'vote', '.'): 0.16834673346531454,
#              ('can', 'vote', '.', 'person', 'c'): 0.14408991030582471,
#              ('vote', '.', 'person', 'c', 'is'): 0.16834673346531454,
#              ('.', 'person', 'c', 'is', 'just'): 0.06273556734402996,
#              ('person', 'c', 'is', 'just', 'as'): 0.16834673346531454,
#              ('c', 'is', 'just', 'as', 'dumb'): 0.16834673346531454,
#              ('is', 'just', 'as', 'dumb', 'as'): 0.16834673346531454,
#              ('just', 'as', 'dumb', 'as', 'person'): 0.16834673346531454,
#              ('as', 'dumb', 'as', 'person', 'a.'): 0.16834673346531454,
#              ('dumb', 'as', 'person', 'a.', 'they'): 0.16834673346531454,
#              ('as', 'person', 'a.', 'they', "'re"): 0.16834673346531454,
#              ('person', 'a.', 'they', "'re", 'not'): 0.16834673346531454,
#              ('a.', 'they', "'re", 'not', 'sure'): 0.16834673346531454,
#              ('they', "'re", 'not', 'sure', 'why'): 0.09107462483576319,
#              ("'re", 'not', 'sure', 'why', 'people'): 0.060716618943881404,
#              ('not', 'sure', 'why', 'people', 'speak'): 0.030358613051999623,
#              ('sure', 'why', 'people', 'speak', 'french'): 0.16834673346531454,
#              ('why', 'people', 'speak', 'french', 'in'): 0.16834673346531454,
#              ('people',
#               'speak',
#               'french',
#               'in',
#               'montreal'): 0.16834673346531454,
#              ('speak',
#               'french',
#               'in',
#               'montreal',
#               'despite'): 0.16834673346531454,
#              ('french',
#               'in',
#               'montreal',
#               'despite',
#               'having'): 0.16834673346531454,
#              ('in',
#               'montreal',
#               'despite',
#               'having',
#               'lived'): 0.16834673346531454,
#              ('montreal',
#               'despite',
#               'having',
#               'lived',
#               'in'): 0.16834673346531454,
#              ('despite',
#               'having',
#               'lived',
#               'in',
#               'canada'): 0.16834673346531454,
#              ('having', 'lived', 'in', 'canada', 'their'): 0.16834673346531454,
# ...
#              ("n't", 'work', '.', 'i', 'wo'): 0.013524705897627599,
#              ('work', '.', 'i', 'wo', "n't"): 0.16834673346531454,
#              ('.', 'i', 'wo', "n't", 'allow'): 0.0036367951543244043,
#              ('i', 'wo', "n't", 'allow', 'my'): 0.14409011792099408,
#              ('wo', "n't", 'allow', 'my', 'kids'): 0.16834673346531454,
#              ("n't", 'allow', 'my', 'kids', 'to'): 0.16834673346531454,
#              ('allow', 'my', 'kids', 'to', 'go'): 0.14409011792099408,
#              ('my', 'kids', 'to', 'go', 'to'): 0.16834673346531454,
#              ('kids', 'to', 'go', 'to', 'college'): 0.6131478731611171,
#              ('to', 'go', 'to', 'college', 'without'): 0.010312558136465129,
#              ('go', 'to', 'college', 'without', 'having'): 0.2518840740330267,
#              ('to',
#               'college',
#               'without',
#               'having',
#               'worked'): 0.14409011792099408,
#              ('college',
#               'without',
#               'having',
#               'worked',
#               'first'): 0.16834673346531454,
#              ('without',
#               'having',
#               'worked',
#               'first',
#               '.'): 0.16834673346531454,
#              ('having', 'worked', 'first', '.', 'i'): 0.16834673346531454,
#              ('worked', 'first', '.', 'i', "'m"): 0.16834673346531454,
#              ('first', '.', 'i', "'m", 'not'): 0.26773465486498205,
#              ('.', 'i', "'m", 'not', 'restricting'): 0.00012208854791986618,
#              ('i', "'m", 'not', 'restricting', 'this'): 0.16834673346531454,
#              ("'m",
#               'not',
#               'restricting',
#               'this',
#               'purely'): 0.16834673346531454,
#              ('not',
#               'restricting',
#               'this',
#               'purely',
#               'to'): 0.16834673346531454,
#              ('restricting',
#               'this',
#               'purely',
#               'to',
#               'retail'): 0.16834673346531454,
#              ('this', 'purely', 'to', 'retail', ','): 0.16834673346531454,
#              ('purely', 'to', 'retail', ',', 'but'): 0.16834673346531454,
#              ('to', 'retail', ',', 'but', 'retail'): 0.16834673346531454,
#              ('retail', ',', 'but', 'retail', 'teaches'): 0.16834673346531454,
#              (',',
#               'but',
#               'retail',
#               'teaches',
#               'humility'): 0.16834673346531454,
#              ('but',
#               'retail',
#               'teaches',
#               'humility',
#               '.'): 0.16834673346531454,
#              ('retail', 'teaches', 'humility', '.', 'it'): 0.16834673346531454,
#              ('teaches',
#               'humility',
#               '.',
#               'it',
#               'teaches'): 0.16834673346531454,
#              ('humility', '.', 'it', 'teaches', 'you'): 0.16834673346531454,
#              ('.', 'it', 'teaches', 'you', 'how'): 0.14409011792099408,
#              ('it', 'teaches', 'you', 'how', 'to'): 0.28817735409726464,
#              ('teaches', 'you', 'how', 'to', 'be'): 0.01787657686130771,
#              ('you', 'how', 'to', 'be', 'diplomatic'): 0.07173621114127161,
#              ('how', 'to', 'be', 'diplomatic', ','): 0.16834673346531454,
#              ('to', 'be', 'diplomatic', ',', 'how'): 0.16834673346531454,
#              ('be', 'diplomatic', ',', 'how', 'you'): 0.16834673346531454,
#              ('diplomatic', ',', 'how', 'you', "'re"): 0.16834673346531454,
#              (',', 'how', 'you', "'re", 'not'): 0.14409011792099408,
#              ('how', 'you', "'re", 'not', 'the'): 0.06693466771618128,
#              ('you', "'re", 'not', 'the', 'center'): 0.027793341945506145,
#              ("'re", 'not', 'the', 'center', 'of'): 0.37782485164176394,
#              ('not', 'the', 'center', 'of', 'the'): 0.6693346291625837,
#              ('the', 'center', 'of', 'the', 'universe'): 0.04653540233179138,
#              ('center', 'of', 'the', 'universe', ','): 0.250233968468057,
#              ('of',
#               'the',
#               'universe',
#               ',',
#               'sometimes'): 0.0038769445201725797,
#              ('the', 'universe', ',', 'sometimes', 'you'): 0.16834673346531454,
#              ('universe',
#               ',',
#               'sometimes',
#               'you',
#               'have'): 0.16834673346531454,
#              (',', 'sometimes', 'you', 'have', 'to'): 0.5484358661235951,
#              ('sometimes',
#               'you',
#               'have',
#               'to',
#               'tolerate'): 0.01820195907407758,
#              ('you', 'have', 'to', 'tolerate', 'shit'): 0.14409011792099408,
#              ('have', 'to', 'tolerate', 'shit', ','): 0.16834673346531454,
#              ('to', 'tolerate', 'shit', ',', 'things'): 0.16834673346531454,
#              ('tolerate', 'shit', ',', 'things', 'wo'): 0.16834673346531454,
#              ('shit', ',', 'things', 'wo', "n't"): 0.16834673346531454,
#              (',', 'things', 'wo', "n't", 'always'): 0.14409011792099408,
#              ('things', 'wo', "n't", 'always', 'go'): 0.16834673346531454,
#              ('wo', "n't", 'always', 'go', 'your'): 0.11185605755550189,
#              ("n't", 'always', 'go', 'your', 'way'): 0.28817735409726464,
#              ('always', 'go', 'your', 'way', '.'): 0.14409011792099408,
#              ('go', 'your', 'way', '.', 'and'): 0.11185605755550189,
#              ('your', 'way', '.', 'and', 'after'): 0.14409011792099408,
#              ('way', '.', 'and', 'after', 'working'): 0.16834673346531454,
#              ('.', 'and', 'after', 'working', 'a'): 0.14409011792099408,
#              ('and', 'after', 'working', 'a', 'retail'): 0.16834673346531454,
#              ('after', 'working', 'a', 'retail', 'job'): 0.16834673346531454,
#              ('working', 'a', 'retail', 'job', ','): 0.16834673346531454,
#              ('a', 'retail', 'job', ',', 'you'): 0.14409011792099408,
#              ('retail', 'job', ',', 'you', "'ll"): 0.16834673346531454,
#              ('job', ',', 'you', "'ll", 'treat'): 0.07727986497932034,
#              (',', 'you', "'ll", 'treat', 'other'): 0.14409011792099408,
#              ('you', "'ll", 'treat', 'other', 'retail'): 0.16834673346531454,
#              ("'ll",
#               'treat',
#               'other',
#               'retail',
#               'workers'): 0.16834673346531454,
#              ('treat',
#               'other',
#               'retail',
#               'workers',
#               'with'): 0.16834673346531454,
#              ('other',
#               'retail',
#               'workers',
#               'with',
#               'more'): 0.16834673346531454,
#              ('retail',
#               'workers',
#               'with',
#               'more',
#               'respect'): 0.16834673346531454,
#              ('workers', 'with', 'more', 'respect', '.'): 0.16834673346531454,
#              ('with', 'more', 'respect', '.', 'having'): 0.11185605755550189,
#              ('more', 'respect', '.', 'having', 'a'): 0.16834673346531454,
#              ('respect', '.', 'having', 'a', 'job'): 0.16834673346531454,
#              ('.', 'having', 'a', 'job', 'also'): 0.14409011792099408,
#              ('having', 'a', 'job', 'also', 'teaches'): 0.16834673346531454,
#              ('a', 'job', 'also', 'teaches', 'the'): 0.16834673346531454,
#              ('job', 'also', 'teaches', 'the', 'reality'): 0.16834673346531454,
#              ('also', 'teaches', 'the', 'reality', 'of'): 0.16834673346531454,
#              ('teaches', 'the', 'reality', 'of', 'the'): 0.16834673346531454,
#              ('the', 'reality', 'of', 'the', 'world'): 0.1476859953291946,
#              ('reality', 'of', 'the', 'world', 'versus'): 0.05574172920763603,
#              ('of', 'the', 'world', 'versus', 'theory'): 0.14409011792099408,
#              ('the', 'world', 'versus', 'theory', '.'): 0.16834673346531454,
#              ('world', 'versus', 'theory', '.', 'i'): 0.16834673346531454,
#              ('versus', 'theory', '.', 'i', 'used'): 0.16834673346531454,
#              ('theory', '.', 'i', 'used', 'to'): 0.16834673346531454,
#              ('.', 'i', 'used', 'to', 'be'): 0.1885539788624085,
#              ('i', 'used', 'to', 'be', 'a'): 0.2886880975638635,
#              ('used', 'to', 'be', 'a', 'hardcore'): 0.007144453401911781,
#              ('to', 'be', 'a', 'hardcore', 'republican'): 0.12594329642428945,
#              ('be', 'a', 'hardcore', 'republican', 'who'): 0.16834673346531454,
#              ('a',
#               'hardcore',
#               'republican',
#               'who',
#               'thought'): 0.16834673346531454,
#              ('hardcore',
#               'republican',
#               'who',
#               'thought',
#               'poor'): 0.16834673346531454,
#              ('republican',
#               'who',
#               'thought',
#               'poor',
#               'people'): 0.16834673346531454,
#              ('who', 'thought', 'poor', 'people', 'did'): 0.16834673346531454,
#              ('thought', 'poor', 'people', 'did', "n't"): 0.16834673346531454,
#              ('poor', 'people', 'did', "n't", 'have'): 0.16834673346531454,
#              ('people', 'did', "n't", 'have', 'it'): 0.035791389050344596,
#              ('did', "n't", 'have', 'it', 'that'): 0.005749215937611677,
#              ("n't", 'have', 'it', 'that', 'bad'): 0.16834673346531454,
#              ('have', 'it', 'that', 'bad', 'and'): 0.16834673346531454,
#              ('it', 'that', 'bad', 'and', 'wealthy'): 0.16834673346531454,
#              ('that', 'bad', 'and', 'wealthy', 'people'): 0.16834673346531454,
#              ('bad',
#               'and',
#               'wealthy',
#               'people',
#               'deserve'): 0.16834673346531454,
#              ('and',
#               'wealthy',
#               'people',
#               'deserve',
#               'to'): 0.16834673346531454,
#              ('wealthy',
#               'people',
#               'deserve',
#               'to',
#               'live'): 0.16834673346531454,
#              ('people', 'deserve', 'to', 'live', '100x'): 0.14409011792099408,
#              ('deserve', 'to', 'live', '100x', 'better'): 0.16834673346531454,
#              ('to', 'live', '100x', 'better', 'because'): 0.16834673346531454,
#              ('live',
#               '100x',
#               'better',
#               'because',
#               'they'): 0.16834673346531454,
#              ('100x',
#               'better',
#               'because',
#               'they',
#               'work'): 0.16834673346531454,
#              ('better',
#               'because',
#               'they',
#               'work',
#               'harder'): 0.16834673346531454,
#              ('because', 'they', 'work', 'harder', '.'): 0.14409011792099408,
#              ('they', 'work', 'harder', '.', 'now'): 0.16834673346531454,
#              ('work', 'harder', '.', 'now', ','): 0.28817735409726464,
#              ('harder', '.', 'now', ',', 'i'): 0.14409011792099408,
#              ('.', 'now', ',', 'i', 'see'): 0.01018782482922206,
#              ('now', ',', 'i', 'see', 'the'): 0.13386799676578157,
#              (',', 'i', 'see', 'the', 'real'): 0.022758637640577294,
#              ('i', 'see', 'the', 'real', 'challenges'): 0.16834673346531454,
#              ('see',
#               'the',
#               'real',
#               'challenges',
#               'average'): 0.16834673346531454,
#              ('the',
#               'real',
#               'challenges',
#               'average',
#               'people'): 0.16834673346531454,
#              ('real',
#               'challenges',
#               'average',
#               'people',
#               'face'): 0.16834673346531454,
#              ('challenges',
#               'average',
#               'people',
#               'face',
#               ','): 0.16834673346531454,
#              ('average',
#               'people',
#               'face',
#               ',',
#               'especially'): 0.16834673346531454,
#              ('people', 'face', ',', 'especially', 'in'): 0.16834673346531454,
#              ('face', ',', 'especially', 'in', 'the'): 0.16834673346531454,
#              (',', 'especially', 'in', 'the', 'ghetto'): 0.003521938278279966,
#              ('especially', 'in', 'the', 'ghetto', '.'): 0.16834673346531454,
#              ('in', 'the', 'ghetto', '.', 'having'): 0.07173621114127161,
#              ('the', 'ghetto', '.', 'having', 'real'): 0.16834673346531454,
#              ('ghetto', '.', 'having', 'real', 'world'): 0.16834673346531454,
#              ('.',
#               'having',
#               'real',
#               'world',
#               'experience'): 0.16834673346531454,
#              ('having',
#               'real',
#               'world',
#               'experience',
#               'will'): 0.16834673346531454,
#              ('real',
#               'world',
#               'experience',
#               'will',
#               'help'): 0.16834673346531454,
#              ('world',
#               'experience',
#               'will',
#               'help',
#               'you'): 0.16834673346531454,
#              ('experience',
#               'will',
#               'help',
#               'you',
#               'just'): 0.10060320475159555,
#              ('will', 'help', 'you', 'just', 'as'): 0.16834673346531454,
#              ('help', 'you', 'just', 'as', 'much'): 0.16834673346531454,
#              ('you', 'just', 'as', 'much', '('): 0.09140750111514923,
#              ('just', 'as', 'much', '(', 'you'): 0.12594329642428945,
#              ('as', 'much', '(', 'you', "'ll"): 0.16834673346531454,
#              ('much', '(', 'you', "'ll", 'encounter'): 0.16834673346531454,
#              ('(', 'you', "'ll", 'encounter', 'lots'): 0.16834673346531454,
#              ('you', "'ll", 'encounter', 'lots', 'of'): 0.16834673346531454,
#              ("'ll", 'encounter', 'lots', 'of', 'people'): 0.16834673346531454,
#              ('encounter', 'lots', 'of', 'people', ','): 0.16834673346531454,
#              ('lots', 'of', 'people', ',', 'learn'): 0.06273556734402996,
#              ('of', 'people', ',', 'learn', 'your'): 0.16834673346531454,
#              ('people',
#               ',',
#               'learn',
#               'your',
#               'strengths'): 0.16834673346531454,
#              (',', 'learn', 'your', 'strengths', 'and'): 0.16834673346531454,
#              ('learn',
#               'your',
#               'strengths',
#               'and',
#               'weaknesses'): 0.16834673346531454,
#              ('your',
#               'strengths',
#               'and',
#               'weaknesses',
#               ')'): 0.06273556734402996,
#              ('strengths', 'and', 'weaknesses', ')', ','): 0.16834673346531454,
#              ('and', 'weaknesses', ')', ',', 'if'): 0.16834673346531454,
#              ('weaknesses', ')', ',', 'if', 'not'): 0.16834673346531454,
#              (')', ',', 'if', 'not', 'more'): 0.14409011792099408,
#              (',', 'if', 'not', 'more', 'than'): 0.05271500654713834,
#              ('if', 'not', 'more', 'than', 'spending'): 0.06273556734402996,
#              ('not', 'more', 'than', 'spending', 'years'): 0.16834673346531454,
#              ('more', 'than', 'spending', 'years', 'in'): 0.16834673346531454,
#              ('than',
#               'spending',
#               'years',
#               'in',
#               'college'): 0.16834673346531454,
#              ('spending', 'years', 'in', 'college', '``'): 0.16834673346531454,
#              ('years', 'in', 'college', '``', 'finding'): 0.16834673346531454,
#              ('in',
#               'college',
#               '``',
#               'finding',
#               'yourself'): 0.16834673346531454,
#              ('college',
#               '``',
#               'finding',
#               'yourself',
#               '.'): 0.16834673346531454,
#              ('``', 'finding', 'yourself', '.', "''"): 0.16834673346531454,
#              ('finding', 'yourself', '.', "''", 'if'): 0.16834673346531454,
#              ('yourself', '.', "''", 'if', 'you'): 0.2518840740330267,
#              ('.', "''", 'if', 'you', 'have'): 0.08697272512438955,
#              ("''", 'if', 'you', 'have', 'no'): 0.05271500654713834,
#              ...})

# %% [markdown]
# ## Evaluate perplexity

# %%
def calculate_perplexity(test_tokens, ngram_probabilities, n):
    """Calculates the perplexity of a test corpus given n-gram probabilities."""
    log_probability_sum = 0
    ngram_count = 0
    
    for i in range(len(test_tokens)-n+1):
        ngram = tuple(test_tokens[i:i+n])
        log_probability_sum += math.log2(ngram_probabilities[ngram])
        ngram_count += 1
    
    average_log_probability = -log_probability_sum / ngram_count
    perplexity = math.pow(2, average_log_probability)
    
    return perplexity

# %%
calculate_perplexity(train_tokens, ngram_probabilities, n)
# Out:
# 5.870205936220359

# %%
calculate_perplexity(test_tokens, ngram_probabilities, n)
# Out:
# 15608.159787834793

# %%
def greedy_sampling(context, vocab, ngram_probabilities, n, max_length = 50):
    
    sentence = []

    if len(context) < (n-1):
        print("len(context) < n")
        return sentence

    context = context[-(n-1):]
    
    for i in range(max_length):

        probs = dict()
        
        for v in vocab:

            ngram = list(context)
            ngram.append(v)
            ngram = tuple(ngram)
            probs[v] = ngram_probabilities[ngram]

        best_token = max(probs, key=probs.get) # greedy 
        #print(best_v)
        #print(probs[best_v])
        
        if probs[best_token] == 0:
            print("prob = 0")
            return sentence
            
        sentence.append(best_token)
        context = list(context)[1:]
        context.append(best_token)
        context = tuple(context)
            
    return sentence

# %%
context = ['i', "'m", 'in', 'honduras']
context = ['the', 'one', 'at', 'the']
sentence = greedy_sampling(context, vocab, ngram_probabilities, n, max_length = 200)
print(" ".join(context) + " " +  " ".join(sentence))
# Out:
# the one at the top of the page for who ) . congratulations to -2 for each side who gave me the most ( see the top of the page for who ) . congratulations to -2 for each side who gave me the most ( see the top of the page for who ) . congratulations to -2 for each side who gave me the most ( see the top of the page for who ) . congratulations to -2 for each side who gave me the most ( see the top of the page for who ) . congratulations to -2 for each side who gave me the most ( see the top of the page for who ) . congratulations to -2 for each side who gave me the most ( see the top of the page for who ) . congratulations to -2 for each side who gave me the most ( see the top of the page for who ) . congratulations to -2 for each side who gave me the most ( see the top of the page for who ) . congratulations to -2 for each side who gave me the most ( see the top of

# %%
train_strings[:250]
# Out:
# "white girls very rarely date asian men. even in asia white men are much more popular than asian men. even though an asian guy may have a preference for white girls he doesn't have much of a chance with one so he should instead pursue a non-white girl"

# %% [markdown]
# # Using NLTK.lm

# %% [markdown]
# ## Import dataset and prepare training and test sets

# %%
# !pip install -U nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.2.4)
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.1)
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.4
#     Uninstalling nltk-3.2.4:
#       Successfully uninstalled nltk-3.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.8.1 which is incompatible.
# Successfully installed nltk-3.8.1

# %%
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm import MLE, StupidBackoff, Laplace

# %%
train_sents = sent_tokenize(train_strings)
print(len(train_sents))
train_sents_tokens = [word_tokenize(s) for s in train_sents]

test_sents = sent_tokenize(test_strings)
print(len(test_sents))
test_sents_tokens = [word_tokenize(s) for s in test_sents]
# Out:
# 3942769
# 4637

# %%
test_sents_tokens[:2]
# Out:
# [['white', 'girls', 'very', 'rarely', 'date', 'asian', 'men', '.'],
#  ['even',
#   'in',
#   'asia',
#   'white',
#   'men',
#   'are',
#   'much',
#   'more',
#   'popular',
#   'than',
#   'asian',
#   'men',
#   '.']]

# %%
n = 3

train, vocab = padded_everygram_pipeline(n, train_sents_tokens)

#lm = MLE(n) # Maximum Likelihood Estimate
#lm = StupidBackoff(order = n) # Stupid Backoff
lm = Laplace(n) # Laplace smoothing

# %%
lm.fit(train, vocab)
print(lm.vocab)
print(len(lm.vocab))
# Out:
# <Vocabulary with cutoff=1 unk_label='<UNK>' and 493886 items>
# 493886

# %%
lm.vocab.lookup(["I", "am"])
# Out:
# ('<UNK>', 'am')

# %%
print(lm.counts)
# Out:
# <NgramCounter with 3 ngram orders and 267839025 ngrams>

# %%
lm.counts['people']
# Out:
# 140218

# %%
lm.score("people")
# Out:
# 0.0014962066909790428

# %%
lm.perplexity(train_sents_tokens)

# %%
lm.perplexity(test_sents_tokens)

# %%
lm.generate(20, random_seed=42)

# %%
lm.generate(20, text_seed=['i'], random_seed=42)
