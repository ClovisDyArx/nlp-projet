# %%
# !pip install pandas seaborn matplotlib scikit-learn gensim eli5 tiktoken spacy gensim wordcloud datasets
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Collecting eli5
#   Downloading eli5-0.13.0.tar.gz (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.2/216.2 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Collecting datasets
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Requirement already satisfied: attrs>17.1.0 in /usr/local/lib/python3.10/dist-packages (from eli5) (23.2.0)
# Requirement already satisfied: jinja2>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from eli5) (3.1.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from eli5) (1.16.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from eli5) (0.20.3)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from eli5) (0.9.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.7.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.5 MB/s eta 0:00:00
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 6.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Collecting huggingface-hub>=0.21.2 (from datasets)
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=3.0.0->eli5) (2.1.5)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.1)
# Building wheels for collected packages: eli5
#   Building wheel for eli5 (setup.py) ... done
#   Created wheel for eli5: filename=eli5-0.13.0-py2.py3-none-any.whl size=107720 sha256=645068bea8c6e36129a2691e157db377004dbbe1c78c4c0c25a5939041e7b334
#   Stored in directory: /root/.cache/pip/wheels/b8/58/ef/2cf4c306898c2338d51540e0922c8e0d6028e07007085c0004
# Successfully built eli5
# Installing collected packages: xxhash, dill, tiktoken, multiprocess, huggingface-hub, eli5, datasets
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# Successfully installed datasets-2.19.1 dill-0.3.8 eli5-0.13.0 huggingface-hub-0.23.0 multiprocess-0.70.16 tiktoken-0.7.0 xxhash-3.4.1

# %%
import tiktoken
import pandas as pd
import numpy as np
import nltk

import matplotlib.pyplot as plt
from datasets import load_dataset
from gensim.models import Word2Vec, KeyedVectors
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.utils.class_weight import compute_sample_weight
from nltk import word_tokenize, sent_tokenize
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.metrics import classification_report, accuracy_score, ConfusionMatrixDisplay, confusion_matrix

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Dataset loading

# %%
dataset = load_dataset("yaful/DeepfakeTextDetect")

# Load the train dataset
df = dataset["train"].to_pandas()
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading data:   0%|          | 0.00/233M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.3M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.13M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/319071 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/56792 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/56819 [00:00<?, ? examples/s]
# Generating test_ood_gpt split:   0%|          | 0/1562 [00:00<?, ? examples/s]
# Generating test_ood_gpt_para split:   0%|          | 0/2362 [00:00<?, ? examples/s]
#                                                 text  label        src
# 0  White girls very rarely date Asian men. Even i...      1  cmv_human
# 1  I am a 23 year old male Indian American male. ...      1  cmv_human
# 2  Take three people, Persons A, B, and C. They l...      1  cmv_human
# 3  (A) Work part-time in high school; Then go to ...      1  cmv_human
# 4  When police introduce a new form of speed prev...      1  cmv_human

# %%
val_count = df.label.value_counts()

plt.figure(figsize=(8,4))
plt.bar(val_count.index, val_count.values)
plt.title("Data Distribution")
# Out:
# Text(0.5, 1.0, 'Data Distribution')

# %% [markdown]
# ## Preprocessing

# %%
def preprocess_text(text):
    # Text to lowercase
    text = text.lower()

    list_text = text.split()

    # Remove stopwords
    list_stopwords = set(nltk.corpus.stopwords.words("english"))
    list_text = [word for word in list_text if word not in list_stopwords]

    # Lemmetize
    lem = nltk.stem.wordnet.WordNetLemmatizer()
    list_text = [lem.lemmatize(word) for word in list_text]

    text = " ".join(list_text)
    return text

# %% [markdown]
# ## Training Word2Vec

# %%
# Check if df.pkl exists
try:
    df = pd.read_pickle("df.pkl")
except:
    df["text_preprocess"] = df["text"].apply(lambda x: preprocess_text(x))
    df.to_pickle("df.pkl")

# %%
# Save time when retry new model
if "df" not in locals():
    df = pd.read_pickle("df.pkl")
X_list = list(df["text_preprocess"])
X_strings = " ".join(X_list)
X_sents = sent_tokenize(X_strings)
X_sents = [word_tokenize(s) for s in X_sents]
X_sents
# Out:
# [['white', 'girl', 'rarely', 'date', 'asian', 'men', '.'],
#  ['even', 'asia', 'white', 'men', 'much', 'popular', 'asian', 'men', '.'],
#  ['even',
#   'though',
#   'asian',
#   'guy',
#   'may',
#   'preference',
#   'white',
#   'girl',
#   'much',
#   'chance',
#   'one',
#   'instead',
#   'pursue',
#   'non-white',
#   'girl',
#   '.'],
#  ['asian',
#   'guy',
#   'penalized',
#   'look',
#   'see',
#   'significantly',
#   'le',
#   'social',
#   ',',
#   'athletic',
#   ',',
#   'intelligent',
#   ',',
#   'wealthy',
#   ',',
#   'etc',
#   '.'],
#  ['facial', 'look', 'genetic', 'can', 'not', 'changed', 'easily', '.'],
#  ['fit', 'body', 'help', 'nearly', 'much', 'white', 'black', 'guys', '.'],
#  ['wish', 'true', '.'],
#  ['edit',
#   ':',
#   'basically',
#   'i',
#   "'m",
#   'saying',
#   'asian',
#   'men',
#   'significant',
#   'disadvantage',
#   'dating',
#   'scene',
#   'especially',
#   'attracted',
#   'white',
#   'women',
#   ',',
#   'comment',
#   'far',
#   'seem',
#   'confirming',
#   'view',
#   '.'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['23', 'year', 'old', 'male', 'indian', 'american', 'male', '.'],
#  ['never',
#   'held',
#   'hand',
#   'girl',
#   ',',
#   'kissed',
#   ',',
#   'obviously',
#   'sex',
#   '.'],
#  ['never', 'even', 'asked', 'someone', 'out', '.'],
#  ['think', 'girl', 'expressed', 'even', 'slightest', 'interest', 'me', '.'],
#  ['graduated',
#   'college',
#   'last',
#   'year',
#   'start',
#   'med',
#   'school',
#   'month',
#   '.'],
#  ['fat',
#   'year',
#   'lost',
#   'weight',
#   'past',
#   'year',
#   'pretty',
#   'fit',
#   'now',
#   '.'],
#  ['5ft', '4', 'tall', 'however', '.'],
#  ['think', 'facially', 'slight', 'average', 'call', 'ugly', '.'],
#  ['family',
#   'struggled',
#   'financially',
#   'focused',
#   'academic',
#   'like',
#   'madman',
#   'able',
#   'go',
#   'great',
#   'college',
#   'headed',
#   'great',
#   'med',
#   'school',
#   '.'],
#  ['ticket', 'better', 'life', '.'],
#  ['yet', 'believe', 'strongly', 'life', 'one', 'loneliness', '.'],
#  ['internally',
#   'angry',
#   'bitter',
#   'even',
#   'friend',
#   'think',
#   'must',
#   'happy',
#   'start',
#   'next',
#   'chapter',
#   'life',
#   '.'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['take',
#   'three',
#   'people',
#   ',',
#   'person',
#   'a',
#   ',',
#   'b',
#   ',',
#   'c.',
#   'live',
#   'us',
#   '.'],
#  ['person', 'born', 'citizen', '.'],
#  ['happen', 'huge', 'idiot', 'even', 'know', 'president', 'does', '.'],
#  ['right',
#   'vote',
#   'literally',
#   'requirement',
#   'surviving',
#   '18',
#   'year',
#   'registering',
#   '.'],
#  ['vote', '.'],
#  ['person', 'b', 'basically', 'albert', 'freaking', 'einstein', '.'],
#  ['highest', 'known', 'iq', 'world', '.'],
#  ['know',
#   'every',
#   'position',
#   'candidate',
#   'vote',
#   'utmost',
#   'qualification',
#   '.'],
#  ['this', ',', 'must', 'pas', 'citizenship', 'test', '.'],
#  ['do', ',', 'vote', '.'],
#  ['person',
#   'c',
#   'dumb',
#   'person',
#   'a.',
#   'they',
#   "'re",
#   'sure',
#   'people',
#   'speak',
#   'french',
#   'montreal',
#   'despite',
#   'lived',
#   'canada',
#   'entire',
#   'life',
#   '.'],
#  ['moved',
#   'u',
#   'unable',
#   'pas',
#   'citizenship',
#   'test',
#   'living',
#   'u',
#   'requisite',
#   'time',
#   '.'],
#  ['can', 'not', 'vote', '.'],
#  ['person', 'b', 'qualified', 'vote', ',', 'yet', 'person', 'b', 'so', '.'],
#  ['person', 'take', 'test', 'person', 'b', 'c', 'vote', '?'],
#  ['edit', ':', 'people', 'already', 'changed', 'view', '.'],
#  ['(', 'if', 'something', 'new', 'say', ',', 'though', ',', 'say', 'it', '!'],
#  ['i', "'m", 'interested', 'people', 'think', '.', ')'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['(',
#   'a',
#   ')',
#   'work',
#   'part-time',
#   'high',
#   'school',
#   ';',
#   'go',
#   'college',
#   '(',
#   'b',
#   ')',
#   'work',
#   'full-time',
#   'go',
#   'college',
#   '(',
#   'c',
#   ')',
#   'work',
#   'study',
#   'college',
#   '.'],
#  ['spoiled', 'lazy', 'kid', 'never', 'got', 'job', '.'],
#  ['priority', 'mixed', 'flunked', '.'],
#  ['got', 'job', 'real', 'world', ',', 'painful', ',', 'humbling', '.'],
#  ['gotten',
#   'job',
#   '18',
#   '(',
#   'or',
#   'sooner',
#   ')',
#   ',',
#   'would',
#   "'ve",
#   'done',
#   'much',
#   'better',
#   'college',
#   'learned',
#   'crucial',
#   'life',
#   'lesson',
#   'sooner',
#   '.'],
#  ['there', "'s", 'also', 'lot', 'people', 'deluded', 'spoiled', 'work', '.'],
#  ['allow', 'kid', 'go', 'college', 'without', 'worked', 'first', '.'],
#  ['i',
#   "'m",
#   'restricting',
#   'purely',
#   'retail',
#   ',',
#   'retail',
#   'teach',
#   'humility',
#   '.'],
#  ['teach',
#   'diplomatic',
#   ',',
#   'center',
#   'universe',
#   ',',
#   'sometimes',
#   'tolerate',
#   'shit',
#   ',',
#   'thing',
#   'always',
#   'go',
#   'way',
#   '.'],
#  ['working',
#   'retail',
#   'job',
#   ',',
#   'treat',
#   'retail',
#   'worker',
#   'respect',
#   '.'],
#  ['job', 'also', 'teach', 'reality', 'world', 'versus', 'theory', '.'],
#  ['used',
#   'hardcore',
#   'republican',
#   'thought',
#   'poor',
#   'people',
#   'bad',
#   'wealthy',
#   'people',
#   'deserve',
#   'live',
#   '100x',
#   'better',
#   'work',
#   'harder',
#   '.'],
#  ['now',
#   ',',
#   'see',
#   'real',
#   'challenge',
#   'average',
#   'people',
#   'face',
#   ',',
#   'especially',
#   'ghetto',
#   '.'],
#  ['real',
#   'world',
#   'experience',
#   'help',
#   'much',
#   '(',
#   'you',
#   "'ll",
#   'encounter',
#   'lot',
#   'people',
#   ',',
#   'learn',
#   'strength',
#   'weaknesses',
#   ')',
#   ',',
#   'spending',
#   'year',
#   'college',
#   '``',
#   'finding',
#   'yourself',
#   '.',
#   "''"],
#  ['idea', 'want', 'college', ',', 'going', 'waste', 'lot', 'time', '.'],
#  ['lot',
#   'college',
#   'kid',
#   'entitled',
#   'parentsgovernment',
#   'pay',
#   'everything',
#   '.'],
#  ['think', 'automatically', 'deserve', 'high-paying', 'job', 'graduated', '.'],
#  ['nope', ',', 'got', 'ta', 'work', 'way', 'bottom', '.'],
#  ['nobody', "'s", 'good', 'entry-level', 'job', '.'],
#  ['oh', ',', 'hurt', 'little', 'resume', '.'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['police',
#   'introduce',
#   'new',
#   'form',
#   'speed',
#   'prevention',
#   'easier',
#   'distribution',
#   'ticket',
#   'crack',
#   'speeders',
#   ',',
#   'motivation',
#   'behind',
#   'actually',
#   'make',
#   'difference',
#   '.'],
#  ['whether',
#   'decrease',
#   'chance',
#   'accident',
#   'revenue',
#   'raising',
#   ',',
#   'power',
#   'still',
#   'lie',
#   'completely',
#   'hand',
#   'person',
#   'behind',
#   'wheel',
#   '.'],
#  ['even',
#   'police',
#   'intention',
#   'revenue',
#   'raising',
#   ',',
#   'money',
#   'still',
#   'go',
#   'toward',
#   'hiring',
#   'officers',
#   ',',
#   'putting',
#   'police',
#   'car',
#   'road',
#   'getting',
#   'better',
#   'technology',
#   'combat',
#   'road',
#   'accidents',
#   '.'],
#  ['making',
#   'anyone',
#   'speed',
#   ',',
#   'making',
#   'best',
#   'fact',
#   'people',
#   'going',
#   'speed',
#   ',',
#   'might',
#   'well',
#   'bring',
#   'revenue',
#   'it',
#   '.'],
#  ['edit',
#   ':',
#   'clarified',
#   'referring',
#   'exclusively',
#   'traffic',
#   'offence',
#   'eg',
#   '.'],
#  ['speeding', ',', 'drink', 'driving', 'etc', '.'],
#  ['edit', ':', 'view', 'changed', '.'],
#  ['see',
#   'motivation',
#   'behind',
#   'revenue',
#   'raising',
#   'contradict',
#   'motivation',
#   'police',
#   'service',
#   'created',
#   'have',
#   '.'],
#  ['revenue',
#   'raising',
#   'goal',
#   ',',
#   'police',
#   'service',
#   'would',
#   'wrong',
#   'reasons',
#   ',',
#   'entire',
#   'outcome',
#   'would',
#   'achieve',
#   'would',
#   'counterproductive',
#   'society',
#   'whole',
#   '.'],
#  ['due',
#   'this',
#   ',',
#   'revenue',
#   'raising',
#   'can',
#   'not',
#   'seen',
#   'morally',
#   'sound',
#   '.'],
#  ['love',
#   'eat',
#   'asiatic',
#   'food',
#   'could',
#   'never',
#   'really',
#   'use',
#   'chopstick',
#   'thinking',
#   '``',
#   'wow',
#   ',',
#   'much',
#   'better',
#   'usual',
#   'cutlery',
#   '.',
#   "''"],
#  ['using', 'chopstick', 'best', 'cultural', 'exercise', 'contortion', '.'],
#  ['fork',
#   'knife',
#   'superior',
#   'every',
#   'way',
#   'imagine',
#   'every',
#   'situation',
#   '.'],
#  ['including', ':', 'rice', 'sticky', 'particularly', 'rice', 'sticky', '.'],
#  ['versatility',
#   'eating',
#   'different',
#   'kind',
#   'food',
#   'eating',
#   'manner',
#   'fear',
#   'dreaded',
#   'fall',
#   'food',
#   'hope',
#   'able',
#   'help',
#   'find',
#   'argument',
#   'coerce',
#   'using',
#   'chopsticks',
#   ':',
#   ')',
#   'update',
#   'fact',
#   'i',
#   "'ve",
#   'accepted',
#   'regarding',
#   'chopsticks',
#   ':',
#   'exercise',
#   'fine',
#   'motor',
#   'skill',
#   'give',
#   'time',
#   'taste',
#   'food',
#   'appreciate',
#   'used',
#   'thing',
#   'easier',
#   'clean',
#   ',',
#   'produce',
#   'carry',
#   'superior',
#   'want',
#   'to',
#   ':',
#   'preserve',
#   'integrity',
#   'food',
#   'eat',
#   '(',
#   'if',
#   'want',
#   'break',
#   'grapevine',
#   'mouth',
#   ')',
#   'eat',
#   'crusty',
#   'thing',
#   '(',
#   'popcorns',
#   ',',
#   'cheetos',
#   ',',
#   'peanuts',
#   '...',
#   ')',
#   'without',
#   'dirtying',
#   'hand',
#   'eat',
#   'leaf',
#   'salad',
#   'makeshift',
#   'chopstick',
#   'easily',
#   'makeshift',
#   'knife',
#   'fork',
#   'still',
#   'thing',
#   '2015.',
#   'historically',
#   'better',
#   'stabbing',
#   'enemy',
#   'dinner',
#   '?'],
#  ['let', 'noted', ',', 'spoon', 'spork', 'proposed', 'i', "'m", 'favors', '!'],
#  ['sporfe', ',', 'knifoon', 'spooned', 'knork', 'i', "'m", 'dubious', '.'],
#  ['may',
#   'quite',
#   'situational',
#   'situation',
#   'accept',
#   'chopstick',
#   'superior',
#   '.'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['argument',
#   'gay',
#   'marriage',
#   ',',
#   'people',
#   'often',
#   'use',
#   "'slippery",
#   'slope',
#   "'",
#   'argument',
#   'legalisation',
#   'would',
#   'lead',
#   'polygamous',
#   'marriage',
#   'also',
#   'becoming',
#   'legal',
#   '.'],
#  ['i',
#   "'m",
#   'interested',
#   'arguing',
#   'whether',
#   'happen',
#   ',',
#   'would',
#   'bad',
#   'thing',
#   'did',
#   '.'],
#  ['would',
#   'within',
#   'context',
#   'people',
#   'allowed',
#   'multiple',
#   'marriages',
#   ',',
#   'would',
#   'automatically',
#   'married',
#   'spouse',
#   "'s",
#   'spouse',
#   ',',
#   'although',
#   'could',
#   'choose',
#   'this',
#   '.'],
#  ['personally',
#   'interested',
#   'polygamy',
#   ',',
#   'what',
#   "'s",
#   'wrong',
#   'it',
#   '?'],
#  ['natural', 'human', 'live', 'groups', '.'],
#  ["'tribes",
#   "'",
#   "or'family",
#   "'",
#   'whatever',
#   'would',
#   'like',
#   'call',
#   'it',
#   '.'],
#  ['see',
#   'anything',
#   'wrong',
#   'family',
#   'several',
#   'adult',
#   'act',
#   'role',
#   'model',
#   'children',
#   '.'],
#  ['ca',
#   "n't",
#   'see',
#   'would',
#   'detrimental',
#   'child',
#   'raised',
#   'environment',
#   '.'],
#  ['allowed',
#   'marry',
#   'need',
#   'consenting',
#   'adult',
#   'one',
#   'people',
#   'make',
#   'relationship',
#   'decisions',
#   '.'],
#  ['long', 'sex', 'bias', '(', 'e.g', '.'],
#  ['men',
#   'many',
#   'wife',
#   'way',
#   'around',
#   ')',
#   ',',
#   'think',
#   'people',
#   'make',
#   'decision',
#   'whether',
#   'polygamous',
#   'relationship',
#   'something',
#   'want',
#   '.'],
#  ['retain',
#   'right',
#   'get',
#   'divorced',
#   'spouse',
#   'marries',
#   'someone',
#   'else',
#   'want',
#   'monogamous',
#   'marriage',
#   ',',
#   'like',
#   'people',
#   'retain',
#   'right',
#   'get',
#   'divorce',
#   'spouse',
#   'cheat',
#   'them',
#   '.'],
#  ['people',
#   'sometimes',
#   'argue',
#   'polygamous',
#   'marriage',
#   'saying',
#   'people',
#   'already',
#   'legally',
#   'allowed',
#   'polygamous',
#   'relationships',
#   ',',
#   'get',
#   'married',
#   '?'],
#  ['legal', 'privilege', 'associated', 'it', '?'],
#  ['get',
#   'married',
#   'legal',
#   'benefit',
#   'married',
#   'going',
#   'way',
#   'list',
#   'reasons',
#   '.'],
#  ['getting', 'married', 'way', 'show', 'love', 'someone', '.'],
#  ['big', 'argument', 'going', 'legality', 'would', 'complex', '.'],
#  ['think', 'that', "'s", 'necessarily', 'case', '.'],
#  ['died', 'possession', 'would', 'divided', 'amongst', 'spouses', '.'],
#  ['child',
#   'would',
#   'either',
#   'go',
#   'parent',
#   'claimed',
#   'next',
#   'kin',
#   'want',
#   'them',
#   ',',
#   'fitness',
#   'look',
#   'determined',
#   'court',
#   'law',
#   '.'],
#  ['case',
#   'currently',
#   'child',
#   'whose',
#   'parent',
#   'die',
#   'without',
#   'leaving',
#   'e.g',
#   '.'],
#  ['go', 'uncle', 'uncle', 'b', '?'],
#  ['lot',
#   'example',
#   'legal',
#   'contract',
#   'binding',
#   'group',
#   'people',
#   ',',
#   'applied',
#   'marriage',
#   '?'],
#  ['could',
#   'encouraged',
#   ',',
#   'even',
#   'possibly',
#   'mandatory',
#   ',',
#   'pre-nuptial',
#   'agreement',
#   'define',
#   'legal',
#   'aspect',
#   'marriage',
#   'relating',
#   'property',
#   'ownership',
#   ',',
#   'etc',
#   '.'],
#  ['prior', 'getting', 'married', 'married', 'one', 'person', '.'],
#  ['current', 'spouse', 'also', 'signing', 'document', '.'],
#  ['i', "'m", 'really', 'interested', 'ethical', 'arguments', '.'],
#  ['one', 'person', "'s", 'ethic', 'determine', 'people', 'live', 'lives', '?'],
#  ['example',
#   ',',
#   'think',
#   'would',
#   'ever',
#   'abortion',
#   'personal',
#   'ethical',
#   'reasons',
#   '.'],
#  ['mean', 'i', "'m", 'people', 'option', '.'],
#  ['i',
#   "'m",
#   'really',
#   'interested',
#   'know',
#   'anyone',
#   'good',
#   'argument',
#   'polygamous',
#   'marriages',
#   '.'],
#  ['think',
#   'lot',
#   'people',
#   'personal',
#   'ethical',
#   'reasons',
#   ',',
#   'want',
#   'one',
#   'themselves',
#   ',',
#   'rather',
#   'actually',
#   'good',
#   ',',
#   'justifiable',
#   'reason',
#   '.'],
#  ['please', 'try', 'cmv', '!'],
#  ['i',
#   "'m",
#   'going',
#   'try',
#   'reply',
#   'every',
#   'direct',
#   'response',
#   'me',
#   '.'],
#  ['get',
#   'really',
#   'ped',
#   'people',
#   'cherry-pick',
#   'argument',
#   'ignore',
#   'one',
#   'suit',
#   'them',
#   '.'],
#  ['lot', 'response', 'may', 'take', 'though', 'please', 'patient', '!'],
#  ['saying',
#   'reply',
#   'purely',
#   'i',
#   "'ve",
#   'committed',
#   'responding',
#   ';',
#   'put',
#   'forth',
#   'low-effort',
#   'comment',
#   'get',
#   'low-effort',
#   'answer',
#   '.'],
#  ['edit',
#   ':',
#   'i',
#   "'m",
#   'getting',
#   'bit',
#   'tired',
#   'bed',
#   'anyone',
#   'else',
#   'comment',
#   'feel',
#   'obliged',
#   'stay',
#   'discus',
#   'more',
#   '!'],
#  ['definitely', 'back', 'please', 'keep', 'discussion', 'going', '!'],
#  ['edit2',
#   ':',
#   'right',
#   ',',
#   'there',
#   "'s",
#   'fair',
#   'reply',
#   'going',
#   'them',
#   '.'],
#  ['although',
#   'lot',
#   'later',
#   'comment',
#   'using',
#   'argument',
#   'used',
#   'i',
#   "'m",
#   'still',
#   'determined',
#   'reply',
#   'them',
#   '.'],
#  ['may',
#   'take',
#   'unfortunately',
#   'thing',
#   'need',
#   'doing',
#   ',',
#   'life',
#   ',',
#   'get',
#   'eventually',
#   '!'],
#  ['edit3', ':', 'finally', 'awarded', 'delta', '!'],
#  ['apology',
#   'anyone',
#   'whose',
#   'comment',
#   'missed',
#   ',',
#   'thank',
#   'part',
#   'conversation',
#   '.'],
#  ['entertaining', 'definitely', 'feel', 'lot', 'informed', '.'],
#  ['scroll',
#   'find',
#   'explanation',
#   'delta',
#   ',',
#   'i',
#   "'ll",
#   'give',
#   'here',
#   ':',
#   '``',
#   'while',
#   'still',
#   'think',
#   'nothing',
#   'wrong',
#   'polygamous',
#   'relationship',
#   'concept',
#   'sort',
#   'legal',
#   'commitment',
#   ',',
#   'marriage',
#   '.'],
#  ['could',
#   'kind',
#   'legally',
#   'binding',
#   'partnership',
#   'multiple',
#   'partner',
#   'benefit',
#   'marriage',
#   ',',
#   'recognition',
#   'partnership',
#   'affecting',
#   'thing',
#   'like',
#   'visitation',
#   'right',
#   'legal',
#   'claim',
#   'next',
#   'kin',
#   ',',
#   'marriage',
#   'now',
#   '.'],
#  ['much',
#   'people',
#   'marriage',
#   'living',
#   'together',
#   ',',
#   'thing',
#   'later',
#   'needed',
#   'taken',
#   'apart',
#   '.'],
#  ['way',
#   'predict',
#   'every',
#   'possibility',
#   'pre-nuptial',
#   'agreement',
#   ',',
#   'situation',
#   'could',
#   'get',
#   'complex',
#   'standard',
#   'could',
#   'fallen',
#   'back',
#   'every',
#   'time',
#   '.',
#   "''"],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['first', 'danish', '.'],
#  ['mean',
#   'follow',
#   'american',
#   'politics',
#   ',',
#   'much',
#   'way',
#   'follow',
#   'german',
#   'politics',
#   '.'],
#  ['somethings',
#   'importent',
#   'situation',
#   ',',
#   'thing',
#   'importent',
#   'me',
#   '.'],
#  ['kind', 'like', 'watching', 'football', 'match', 'cheer', 'teams', '.'],
#  ['said', 'find', 'kind', 'scary', 'clinton', 'bush', 'election', '.'],
#  ['king',
#   'denmark',
#   'used',
#   'elected',
#   ',',
#   'thousand',
#   'year',
#   'ago',
#   ',',
#   'became',
#   'normal',
#   'elect',
#   'king',
#   'familly',
#   '.'],
#  ['latter',
#   'always',
#   'oldest',
#   'son',
#   'endeed',
#   'system',
#   'king',
#   'always',
#   'oldest',
#   'son',
#   'old',
#   'king',
#   '.'],
#  ['le', 'true', 'many', 'countries', '.'],
#  ['people',
#   'seem',
#   'rather',
#   'want',
#   'vote',
#   'people',
#   'family',
#   'know',
#   'random',
#   'people',
#   '.'],
#  ['kind',
#   'seems',
#   'like',
#   'america',
#   'getting',
#   'set',
#   'political',
#   'dynasty',
#   'development',
#   'continues',
#   ',',
#   'might',
#   'end',
#   'system',
#   'everyone',
#   'theory',
#   'try',
#   'elected',
#   'president',
#   ',',
#   'practise',
#   'always',
#   'people',
#   'political',
#   'dynasty',
#   'get',
#   'elected',
#   '.'],
#  ['nice', 'view', 'have', '.'],
#  ['please', 'change', 'it', '.'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['post', 'going', 'blunt', '.'],
#  ['want',
#   'show',
#   'exactly',
#   'impacted',
#   'thinking',
#   'people',
#   'around',
#   'me',
#   '.'],
#  ['born', 'u', 'chinese', 'thai', 'descent', '.'],
#  ['child',
#   'grew',
#   'really',
#   'caring',
#   'race',
#   ',',
#   'sort',
#   'assumed',
#   'human',
#   'came',
#   'different',
#   'color',
#   'shape',
#   'normal',
#   '.'],
#  ['even', 'know', 'name', 'different', 'race', 'ethnicities', '.'],
#  ['thing',
#   'really',
#   'aware',
#   'people',
#   'actually',
#   'came',
#   'different',
#   'country',
#   '.'],
#  ['grew',
#   'older',
#   ',',
#   'classmate',
#   'bombarded',
#   'racial',
#   'message',
#   'school',
#   'everywhere',
#   'else',
#   '.'],
#  ['taught', 'white', 'people', 'somehow', 'inherently', 'racist', '.'],
#  ['taught',
#   'everyone',
#   'else',
#   'perfect',
#   'every',
#   'bad',
#   'thing',
#   'throughout',
#   'history',
#   'somehow',
#   'righteous',
#   'justified',
#   '.'],
#  ['started', 'see', 'line', 'forming', '.'],
#  ['white',
#   'kid',
#   'told',
#   'somehow',
#   'responsible',
#   'everything',
#   'people',
#   'past',
#   'did',
#   '.'],
#  ['black', 'kid', 'taught', 'owed', 'something', '.'],
#  ['noticed', 'kid', 'start', 'self-segregating', '.'],
#  ['anything',
#   'dramatic',
#   ',',
#   'one',
#   'attributed',
#   'thing',
#   'taught',
#   ',',
#   'people',
#   'knew',
#   'different',
#   'now',
#   '.'],
#  ['grew', 'older', 'still', '.'],
#  ['started', 'paying', 'attention', 'news', 'internet', ',', '.'],
#  ['race', 'discussed', 'alot', '.'],
#  ['learned', 'affirmative', 'action', 'made', 'blood', 'boil', '.'],
#  ['know', ',', 'asian', 'hurt', 'affirmative', 'action', '.'],
#  ['would',
#   'need',
#   'much',
#   'higher',
#   'sat',
#   'score',
#   'gpa',
#   'black',
#   'person',
#   'get',
#   'school',
#   'choice',
#   '.'],
#  ['started', 'resent', 'black', 'people', 'this', '.'],
#  ['hurt',
#   'entire',
#   'race',
#   'apparently',
#   'performing',
#   'poorly',
#   'entire',
#   'race',
#   'was',
#   "n't",
#   '?'],
#  ['discrimination',
#   'reason',
#   ',',
#   'well',
#   'race',
#   'discriminated',
#   'past',
#   'too',
#   '!'],
#  ['opinion', 'shared', 'friends', '.'],
#  ['led',
#   'u',
#   'think',
#   'case',
#   ',',
#   'black',
#   'people',
#   'try',
#   'much',
#   'lazy',
#   'school',
#   '.'],
#  ['otherwise', 'would', 'need', 'help', '?'],
#  ['infuriated',
#   'learn',
#   'black',
#   'girl',
#   'took',
#   'level',
#   'class',
#   'even',
#   'close',
#   'top',
#   'class',
#   'accepted',
#   'first',
#   'choice',
#   'college',
#   'not',
#   ',',
#   'despite',
#   'excellent',
#   'grade',
#   'test',
#   'scores',
#   '.'],
#  ['went',
#   'college',
#   ',',
#   'made',
#   'sure',
#   'avoid',
#   'going',
#   'black',
#   'doctor',
#   'black',
#   'professional',
#   'fear',
#   'got',
#   'position',
#   'due',
#   'unfair',
#   'preferences',
#   '.'],
#  ['learned', 'black', 'crime', 'rate', ',', 'prison', 'population', '.'],
#  ['started', 'become', 'scared', 'saw', 'black', 'person', 'streets', '.'],
#  ['commentary', 'racist', 'merely', 'solidified', 'opinion', '.'],
#  ['saw',
#   'violent',
#   'black',
#   'neighborhood',
#   'are',
#   ',',
#   'catcalled',
#   'constantly',
#   'black',
#   'men',
#   'streets',
#   ',',
#   'worked',
#   'leasing',
#   'office',
#   'saw',
#   'black',
#   'tenant',
#   'lived',
#   'entirely',
#   'government',
#   'complained',
#   'everything',
#   '.'],
#  ['heard',
#   'race',
#   'entire',
#   'life',
#   'would',
#   'written',
#   '``',
#   'man',
#   'specific',
#   'people',
#   'suck',
#   "''",
#   'rather',
#   'lump',
#   'entire',
#   'race',
#   'together',
#   '.'],
#  ['people',
#   'address',
#   'issue',
#   'everyone',
#   'else',
#   'blame',
#   'people',
#   'actions',
#   ',',
#   'instead',
#   'saying',
#   'hey',
#   ',',
#   'bad',
#   'people',
#   '.'],
#  ['instead',
#   'make',
#   'race',
#   'thing',
#   'bad',
#   'people',
#   'actually',
#   'victims',
#   '.'],
#  ['heard', 'police', 'shooting', 'publicity', 'around', 'them', '.'],
#  ['heard',
#   'riots',
#   ',',
#   'people',
#   'talked',
#   'senseless',
#   'destruction',
#   'justified',
#   'distanced',
#   'scared',
#   'became',
#   '.'],
#  ['started', 'involuntarily', 'see', 'black', 'people', 'threat', '.'],
#  ['friend',
#   'secretly',
#   'talked',
#   'wished',
#   'people',
#   'would',
#   'go',
#   'back',
#   'africa',
#   'could',
#   'live',
#   'peace',
#   '.'],
#  ['past',
#   'couple',
#   'year',
#   'discussion',
#   'race',
#   'seen',
#   'soo',
#   'many',
#   'non-black',
#   'people',
#   'become',
#   'essentially',
#   'racist',
#   ',',
#   'many',
#   'wonderful',
#   'black',
#   'people',
#   'become',
#   'entitled',
#   'vitriolic',
#   '.'],
#  ['basically',
#   ',',
#   'feel',
#   'like',
#   'brought',
#   'kid',
#   'see',
#   'color',
#   'talk',
#   'american',
#   'americans',
#   ',',
#   'rather',
#   'african-american',
#   ',',
#   'asian',
#   'american',
#   ',',
#   'etc',
#   ',',
#   'racism',
#   'would',
#   'soon',
#   'become',
#   'thing',
#   'past',
#   '.'],
#  ['keep',
#   'bringing',
#   'race',
#   'everything',
#   ',',
#   'kid',
#   'start',
#   'drawing',
#   'line',
#   'lumping',
#   'people',
#   'together',
#   'race',
#   ',',
#   'rather',
#   'americans',
#   '.'],
#  ['start', 'noticing', 'hyper-aware', 'difference', 'races', '.'],
#  ['cry',
#   'racism',
#   'every',
#   'situation',
#   'annoys',
#   'people',
#   'defeat',
#   'goal',
#   'ending',
#   'racism',
#   '.'],
#  ['racial',
#   'diversity',
#   'program',
#   'make',
#   'people',
#   'resentful',
#   ',',
#   'make',
#   'benefitting',
#   'party',
#   'feel',
#   'entitled',
#   '.'],
#  ['people', 'chosen', 'merit', 'alone', '.'],
#  ['``',
#   'not',
#   'seeing',
#   'color',
#   "''",
#   'treated',
#   'ignorant',
#   'laughed',
#   'at',
#   ',',
#   'feel',
#   'best',
#   'way',
#   'operate',
#   'ever',
#   'going',
#   'solve',
#   'problems',
#   '.'],
#  ['i',
#   "'d",
#   'like',
#   'opinion',
#   'way',
#   'see',
#   'world',
#   'right',
#   'truly',
#   'sickens',
#   'me',
#   '.'],
#  ['want',
#   'keep',
#   'feeling',
#   'like',
#   'different',
#   'asian',
#   ',',
#   'want',
#   'feel',
#   'american',
#   'okay',
#   'way',
#   'people',
#   'talk',
#   'race',
#   '.'],
#  ['want', 'feel', 'okay', 'way', 'american', 'dealing', 'issues', '.'],
#  ['also',
#   'want',
#   'understand',
#   '``',
#   'not',
#   'seeing',
#   'color',
#   "''",
#   'ridiculed',
#   '.'],
#  ['here', "'s", 'see', 'neighborhood', '6', 'handicapped', 'spots', '.'],
#  ['almost', 'always', 'empty', '.'],
#  ['almost',
#   'everywhere',
#   'go',
#   'city',
#   'i',
#   "'m",
#   'looking',
#   'parking',
#   'handicapped',
#   'spot',
#   'empty',
#   'one',
#   'sometimes',
#   '.'],
#  ['(',
#   'to',
#   'day',
#   ',',
#   'however',
#   ',',
#   'never',
#   'parked',
#   'even',
#   'briefly',
#   'pulled',
#   'handicapped',
#   'spot',
#   'feel',
#   'cruel',
#   '.',
#   ')'],
#  ['time',
#   'see',
#   'occupied',
#   ',',
#   'every',
#   'time',
#   ',',
#   'see',
#   'completely',
#   'able',
#   'bodied',
#   'person',
#   'leave',
#   'car',
#   '.'],
#  ['leg', 'made', 'meat', 'fully', 'functional', '.'],
#  ['handicap', 'badge', 'car', 'seem', 'sort', 'physical', 'ailment', '.'],
#  ['need',
#   'contraption',
#   'get',
#   'wheelchair',
#   'seems',
#   'fair',
#   ',',
#   'person',
#   'deaf',
#   'missing',
#   'pinky',
#   'see',
#   'need',
#   'special',
#   'reserved',
#   'parking',
#   '.'],
#  ['know',
#   'one',
#   'fraudsters',
#   'personally',
#   ',',
#   'grandfather',
#   'handicapped',
#   'used',
#   'handicap',
#   'badge',
#   '.'],
#  ['presumably', 'ok', 'sometimes', 'drive', 'places', '.'],
#  ['kept',
#   'car',
#   'every',
#   'day',
#   'whole',
#   'family',
#   'used',
#   'park',
#   'handicap',
#   'spots',
#   '.'],
#  ['tell',
#   'people',
#   'use',
#   'handicap',
#   'parking',
#   'spot',
#   'people',
#   'handicapped',
#   'relative',
#   'handicapped',
#   'driver',
#   '.'],
#  ['never',
#   'seen',
#   'one',
#   'special',
#   'car',
#   'people',
#   'disabled',
#   'button',
#   'instead',
#   'pedal',
#   'contraption',
#   'unloads',
#   'person',
#   'wheelchair',
#   '.'],
#  ['even',
#   'saw',
#   'actual',
#   'physically',
#   'disabled',
#   'person',
#   'exit',
#   'vehicle',
#   'handicapped',
#   'parking',
#   'spot',
#   'might',
#   'even',
#   'question',
#   'special',
#   'parking',
#   'spots',
#   '.'],
#  ['edit', ':', 'delta', 'awarded', '.'],
#  ['many',
#   'right',
#   'confirmation',
#   'bias',
#   'and',
#   ',',
#   'importantly',
#   ',',
#   'countless',
#   'severe',
#   'visible',
#   'invisible',
#   'disabilities',
#   '.'],
#  ['could', 'spot', 'illness', 'glance', 'would', 'need', 'doctors', '?'],
#  ['thanks', 'everyone', 'hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['understanding',
#   ',',
#   'common',
#   'core',
#   'set',
#   'standard',
#   'skill',
#   'student',
#   'learn',
#   'graduating',
#   'high',
#   'school',
#   '.'],
#  ['though',
#   'still',
#   'quite',
#   'year',
#   'getting',
#   'there',
#   ',',
#   'observed',
#   'school',
#   "'s",
#   'mathematics',
#   'system',
#   'show',
#   'skill',
#   'rely',
#   'heavily',
#   'memorization',
#   'calculation',
#   ',',
#   'much',
#   'le',
#   'reasoning',
#   ',',
#   'virtually',
#   'none',
#   'application',
#   '.'],
#  ['i',
#   "'ve",
#   'looked',
#   'common',
#   'core',
#   'website',
#   'seen',
#   'accurately',
#   'reflect',
#   'standard',
#   'put',
#   'out',
#   '.'],
#  ['let',
#   "'s",
#   'take',
#   '[',
#   'common',
#   'core',
#   'algebra',
#   'standards',
#   ']',
#   'example',
#   '.'],
#  ['scroll',
#   'overview',
#   ',',
#   'see',
#   'almost',
#   'skill',
#   'listed',
#   'solve',
#   'equation',
#   'something',
#   'sort',
#   '.'],
#  ['calculation', '.'],
#  ['common',
#   'core',
#   'currently',
#   'spends',
#   'much',
#   'time',
#   'this',
#   ',',
#   'something',
#   'relatively',
#   'easy',
#   'computer',
#   'it',
#   '.'],
#  ['time', 'need', 'shift', 'branch', 'mathematics', '.'],
#  ['believe',
#   'algebra',
#   ',',
#   'well',
#   'much',
#   'rest',
#   'mathematics',
#   ',',
#   'used',
#   'medium',
#   'logic',
#   'reasoning',
#   'taught',
#   '.'],
#  ['though',
#   'computer',
#   'use',
#   'logic',
#   'extent',
#   ',',
#   'human',
#   'brain',
#   'much',
#   'capable',
#   'used',
#   'needed',
#   'for',
#   '.'],
#  ['[', 'here', 'purely', 'algebraic', 'problem', '.', ']'],
#  ['despite',
#   'concept',
#   'purely',
#   'algebraic',
#   ',',
#   'requires',
#   'high',
#   'level',
#   'critical',
#   'thinking',
#   'reasoning',
#   'order',
#   'solve',
#   '.'],
#  ['type',
#   'multi-step',
#   'problem',
#   'taught',
#   'high',
#   'schools',
#   ',',
#   'almost',
#   'always',
#   'not',
#   '.'],
#  ['common',
#   'core',
#   'require',
#   'student',
#   'display',
#   'level',
#   'critical',
#   'thinking',
#   '.'],
#  ['let', "'s", 'take', '[', 'geometry', 'another', 'example', '.', ']'],
#  ['scroll',
#   'overview',
#   ',',
#   'standard',
#   'somewhat',
#   'better',
#   ',',
#   'since',
#   'introduce',
#   'notion',
#   'proof',
#   '.'],
#  ['however',
#   ',',
#   'close',
#   'inspection',
#   'congruence',
#   'section',
#   ',',
#   'basic',
#   'proof',
#   'spanning',
#   'basic',
#   'proof',
#   'type',
#   'necessary',
#   '.'],
#  ['cover',
#   'important',
#   'proof',
#   'contradiction',
#   'proof',
#   'induction',
#   ',',
#   'two',
#   'kind',
#   'reasoning',
#   'much',
#   'better',
#   'applied',
#   'real',
#   'world',
#   '.'],
#  ['also',
#   'never',
#   'required',
#   'student',
#   'prove',
#   'algebraic',
#   'concepts',
#   ',',
#   'quadratic',
#   'formula',
#   '.'],
#  ['theorem',
#   'geometry',
#   'algebra',
#   'proven',
#   ',',
#   'student',
#   'forced',
#   'memorize',
#   'them',
#   '.'],
#  ['computer', 'that', '.'],
#  ['need', 'people', 'prove', 'reason', '.'],
#  ['also',
#   'important',
#   'concept',
#   'like',
#   'geometry',
#   'taught',
#   'conjunction',
#   'area',
#   'mathematics',
#   ',',
#   'calculus',
#   '.'],
#  ['took',
#   'geometry',
#   '8th',
#   'grade',
#   ',',
#   'though',
#   'bit',
#   'early',
#   'calculus',
#   ',',
#   'idea',
#   'limit',
#   'thing',
#   'like',
#   'least',
#   'touched',
#   'upon',
#   '.'],
#  ['volume', 'pyramid', 'bh3', '?'],
#  ['idea', 'taking', 'function', 'limit', 'make', 'easy', 'prove', 'this', '.'],
#  ['common', 'core', 'cover', 'this', '.'],
#  ['far',
#   ',',
#   'i',
#   "'ve",
#   'touched',
#   'little',
#   'upon',
#   'idea',
#   'application',
#   ',',
#   'mostly',
#   'that',
#   "'s",
#   'difficult',
#   'one',
#   '.'],
#  ['know',
#   'mathematics',
#   'applied',
#   'sort',
#   'stem',
#   'subjects',
#   ',',
#   'student',
#   'already',
#   'set',
#   'taking',
#   'liberal',
#   'art',
#   'major',
#   '?'],
#  ['forced', 'study', 'engineering', 'math', '.'],
#  ['so',
#   ',',
#   'think',
#   'application',
#   'mathematics',
#   'need',
#   'brought',
#   'back',
#   'roots',
#   ',',
#   'application',
#   'logic',
#   '.'],
#  ['programming',
#   'great',
#   'way',
#   'apply',
#   'this',
#   ',',
#   'though',
#   'maybe',
#   'math',
#   'class',
#   'right',
#   'place',
#   'this',
#   ',',
#   'every',
#   'student',
#   'already',
#   'programmable',
#   'graphing',
#   'calculator',
#   'anyway',
#   '.'],
#  ['instead',
#   'forcing',
#   'student',
#   'use',
#   'program',
#   'test',
#   'like',
#   'school',
#   ',',
#   'think',
#   'use',
#   'program',
#   'encouraged',
#   ',',
#   'since',
#   'demonstrate',
#   'understanding',
#   'basis',
#   'behind',
#   'mathematics',
#   ',',
#   'logic',
#   '.'],
#  ['maybe',
#   'straying',
#   'bit',
#   'far',
#   'purpose',
#   'common',
#   'core',
#   ',',
#   'implemented',
#   'guideline',
#   ',',
#   'perhaps',
#   'suggestion',
#   'would',
#   'great',
#   '.'],
#  ['i',
#   "'ll",
#   'going',
#   'common',
#   'core',
#   'years',
#   ',',
#   'want',
#   'know',
#   'effective',
#   '.'],
#  ['please', 'cmv', '.'],
#  ['edit',
#   ':',
#   'forgot',
#   'mention',
#   'think',
#   'reasoning',
#   'much',
#   'important',
#   'formula',
#   'memorized',
#   'real',
#   'world',
#   '.'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['islam',
#   'religion',
#   'spawned',
#   'quran',
#   ',',
#   'religious',
#   'text',
#   'considered',
#   'word',
#   'god',
#   '(',
#   'allah',
#   ')',
#   '.'],
#  ['religion', 'began', 'arabian', 'peninsula', 'early', '600s', '.'],
#  ['islam',
#   'date',
#   ',',
#   'dangerous',
#   'today',
#   "'s",
#   'society',
#   'subversive',
#   ',',
#   'always',
#   'violent',
#   'religion',
#   '.'],
#  ['would', 'fine', 'islam', 'could', 'reformed', '.'],
#  ['that', "'s", 'trouble', 'islam', '.'],
#  ['widely',
#   'reformed',
#   'i',
#   "'m",
#   'afraid',
#   'can',
#   'not',
#   'due',
#   'structure',
#   '.'],
#  ['sure',
#   ',',
#   'similar',
#   'structure',
#   'concept',
#   'dar-al-harbgarbkufr',
#   '(',
#   'war',
#   ',',
#   'war',
#   '(',
#   'ottoman',
#   ')',
#   ',',
#   'infidel',
#   ')',
#   'dar-al-islam',
#   '(',
#   'islampeace',
#   ')',
#   'one',
#   'divide',
#   'world',
#   'two',
#   ';',
#   'nation',
#   'follow',
#   'law',
#   'islam',
#   '(',
#   'shariah',
#   ')',
#   'do',
#   "n't",
#   '.'],
#  ['say',
#   'practice',
#   'outdated',
#   'style',
#   ',',
#   'please',
#   'look',
#   'salafis',
#   ',',
#   'extremist',
#   'group',
#   'middle',
#   'east',
#   ',',
#   '[',
#   'this',
#   'fine',
#   'fellow',
#   'people',
#   'like',
#   'classify',
#   'salafis',
#   ']',
#   '.'],
#  ['even',
#   'quran',
#   'taken',
#   'literally',
#   ',',
#   'shariah',
#   'law',
#   'still',
#   'applies',
#   '.'],
#  ['lived', 'islamic', 'country', '.'],
#  ['need',
#   'take',
#   'hadith',
#   'quran',
#   'literally',
#   'subject',
#   'literal',
#   'shariah',
#   'law',
#   '.'],
#  ['read',
#   'here',
#   ':',
#   'looking',
#   'malaysian',
#   'legal',
#   'system',
#   'whole',
#   ',',
#   'sharia',
#   'law',
#   'play',
#   'relatively',
#   'small',
#   'role',
#   'defining',
#   'law',
#   'country',
#   '.'],
#  ['applies', 'muslims', '.'],
#  ['regard',
#   'civil',
#   'law',
#   ',',
#   'syariah',
#   'court',
#   'jurisdiction',
#   'personal',
#   'law',
#   'matters',
#   ',',
#   'example',
#   'marriage',
#   ',',
#   'inheritance',
#   ',',
#   'apostasy',
#   '.'],
#  ['state',
#   'sharia',
#   'criminal',
#   'laws',
#   ',',
#   'example',
#   'kelantan',
#   'syariah',
#   'criminal',
#   'code',
#   'enactment',
#   '1993.',
#   'jurisdiction',
#   'however',
#   'limited',
#   'imposing',
#   'fine',
#   'amount',
#   'rm',
#   '5000',
#   ',',
#   'imprisonment',
#   '3',
#   'years',
#   '.'],
#  ['august',
#   '2007',
#   ',',
#   'chief',
#   'justice',
#   'malaysia',
#   'proposed',
#   'replace',
#   'current',
#   'common',
#   'law',
#   'application',
#   'malaysia',
#   'sharia',
#   'law',
#   'literally',
#   'go',
#   'jail',
#   'renouncing',
#   'islam',
#   '.'],
#  ['far',
#   'serious',
#   'country',
#   'like',
#   'saudi',
#   'arabia',
#   ',',
#   '4',
#   '10',
#   'muslim',
#   'uk',
#   'want',
#   'establish',
#   'shariah',
#   'law',
#   '.'],
#  ['fact',
#   ',',
#   '85',
#   'shariah',
#   'law',
#   'courthouse',
#   'uk',
#   'run',
#   'court-approval',
#   'basis',
#   '.'],
#  ['personally',
#   'believe',
#   'political',
#   'stress',
#   'plus',
#   'fact',
#   'party',
#   'signed',
#   'agreement',
#   'judged',
#   'shariah',
#   'law',
#   'make',
#   'every',
#   'case',
#   'stamp-and-go',
#   'case',
#   '.'],
#  ['say',
#   'party',
#   'consent',
#   'it',
#   ',',
#   'alright',
#   ',',
#   'please',
#   'think',
#   'cultural',
#   'familial',
#   'pressure',
#   'islam',
#   'treatment',
#   'women',
#   '.'],
#  ['must', 'forget', 'islam', "'s", 'borderline', 'slavery', 'women', '.'],
#  ['covered',
#   ',',
#   'silenced',
#   ',',
#   'veiled',
#   ',',
#   'separated',
#   ',',
#   'treated',
#   'commodity',
#   '.'],
#  ['god',
#   'willing',
#   ',',
#   'least',
#   'inherit',
#   'half',
#   'amount',
#   'man',
#   'level',
#   'descendence',
#   'would',
#   '.'],
#  ['say',
#   'muslim',
#   'bad',
#   'people',
#   'must',
#   'convert',
#   'part',
#   'today',
#   "'s",
#   'society',
#   '.'],
#  ['say', 'all', '.'],
#  ['fact', ',', 'say', 'opposite', '.'],
#  ['anything',
#   'stop',
#   'self-indulgent',
#   'hedonism',
#   'today',
#   "'s",
#   'society',
#   'muslim',
#   '(',
#   'and',
#   'sikhs',
#   ')',
#   '.'],
#  ['say',
#   'islam',
#   'conflict',
#   'today',
#   "'s",
#   'society',
#   ',',
#   'can',
#   'not',
#   'wholly',
#   'compatible',
#   'today',
#   "'s",
#   'world',
#   '.'],
#  ['approve', 'islam', '.'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['i', "'ve", 'lived', 'practically', 'whole', 'life', 'phrase', '.'],
#  ['shaped',
#   'made',
#   'several',
#   'important',
#   'decision',
#   'life',
#   ',',
#   'though',
#   'recently',
#   'come',
#   'suspect',
#   'may',
#   'whole',
#   'truth',
#   '.'],
#  ['phrase',
#   'fairly',
#   'explanatory',
#   ',',
#   'deeper',
#   'meaning',
#   'behind',
#   'always',
#   'looking',
#   'kind',
#   'satisfaction',
#   'behind',
#   'work',
#   ';',
#   'happy',
#   'customer',
#   ',',
#   'well-stocked',
#   'shelf',
#   ',',
#   'cool',
#   'painting',
#   '.'],
#  ['always',
#   'something',
#   'work',
#   'grant',
#   'least',
#   'menial',
#   'satisfaction',
#   ',',
#   'even',
#   'much',
#   'work',
#   'fit',
#   'doing',
#   '.'],
#  ['every',
#   'school',
#   'shooting',
#   'debate',
#   'gun',
#   'violence',
#   'school',
#   'start',
#   'one',
#   'side',
#   'supporting',
#   'reduced',
#   'gun',
#   'right',
#   'side',
#   'supporting',
#   'banning',
#   'violent',
#   'video',
#   'games',
#   '.'],
#  ['whenever',
#   'idea',
#   'posting',
#   'armed',
#   'guard',
#   'school',
#   'brought',
#   'idea',
#   'always',
#   'shot',
#   'ridiculous',
#   '.'],
#  ['never', 'given', 'reason', 'people', 'look', 'upon', 'it', '.'],
#  ['feel',
#   'posting',
#   'armed',
#   'guard',
#   'school',
#   'would',
#   'directly',
#   'deincentivize',
#   'individual',
#   'going',
#   'violent',
#   'crime',
#   'schools',
#   '.'],
#  ['individual',
#   'wanting',
#   'commit',
#   'suicidal',
#   'armed',
#   'guard',
#   'would',
#   'directly',
#   'solve',
#   'problem',
#   'stop',
#   'would-be',
#   'gunman',
#   'tragedy',
#   'even',
#   'starts',
#   '.'],
#  ['idea',
#   'curbing',
#   'gun',
#   'violence',
#   'seem',
#   'aspect',
#   'deincentification',
#   'directness',
#   'posting',
#   'armed',
#   'guard',
#   'school',
#   'has',
#   '.'],
#  ['that',
#   "'s",
#   'say',
#   'idea',
#   'wrong',
#   'adding',
#   'idea',
#   'armed',
#   'guard',
#   'respective',
#   'platform',
#   'would',
#   ',',
#   'opinion',
#   ',',
#   'help',
#   'curb',
#   'school',
#   'violence',
#   'better',
#   'opinion',
#   'could',
#   'individually',
#   '.'],
#  ['edit',
#   ':',
#   'see',
#   'people',
#   'point',
#   'school',
#   'shooting',
#   'rare',
#   'expense',
#   'involved',
#   'would',
#   'great',
#   '.'],
#  ['that', "'s", 'legitimate', 'fair', 'argument', '.'],
#  ['still',
#   'think',
#   'brought',
#   'discussion',
#   'see',
#   'people',
#   'look',
#   'upon',
#   'it',
#   '.'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['human',
#   'sentience',
#   '(',
#   'or',
#   'consciousness',
#   ',',
#   'sapience',
#   ',',
#   'whatever',
#   'term',
#   'like',
#   ')',
#   'emergent',
#   'behavior',
#   'neuron',
#   'interactions',
#   ',',
#   'replicated',
#   'non-organic',
#   'systems',
#   ',',
#   'i.e.',
#   ',',
#   'computers',
#   '.'],
#  ['thus',
#   'likely',
#   'given',
#   'advanced',
#   'enough',
#   'technology',
#   ',',
#   'could',
#   'make',
#   'digital',
#   'human',
#   ',',
#   'even',
#   'copy',
#   'organic',
#   'human',
#   'digital',
#   'world',
#   '.'],
#  ['similarly',
#   ',',
#   'neural',
#   'network',
#   'constructed',
#   'digitally',
#   ',',
#   'collectively',
#   'known',
#   'ai',
#   '.'],
#  ['fairly',
#   'well',
#   'accepted',
#   'modern',
#   'society',
#   ',',
#   'although',
#   'debate',
#   "over'souls",
#   "'",
#   'thing',
#   'like',
#   'that',
#   '.'],
#  ['think',
#   'sentient',
#   'ai',
#   'probably',
#   'emerge',
#   'first',
#   ',',
#   'long',
#   'get',
#   'close',
#   'digitizing',
#   'humans',
#   ',',
#   'way',
#   'ai',
#   'may',
#   'emerge',
#   '.'],
#  ['currently',
#   ',',
#   'one',
#   'approach',
#   'developing',
#   'advanced',
#   'neural',
#   'network',
#   'allow',
#   "grow'naturally",
#   "'",
#   ',',
#   'say',
#   'network',
#   'given',
#   'parameter',
#   'optimize',
#   ',',
#   'iteration',
#   'darwinistically',
#   'decide',
#   'optimal',
#   'solution',
#   'is',
#   '.'],
#  ['pretty',
#   'much',
#   'like',
#   'carbon-based',
#   'evolution',
#   ',',
#   'much',
#   'faster',
#   '.'],
#  ['however',
#   ',',
#   'i',
#   "'m",
#   'expert',
#   'field',
#   ',',
#   'i',
#   "'m",
#   'open',
#   'different',
#   'opinions',
#   ',',
#   'even',
#   'alternative',
#   'two',
#   'options',
#   '.'],
#  ['cmv',
#   ':',
#   'ai',
#   'achieve',
#   'sentience',
#   'way',
#   'make',
#   'computer',
#   'humans',
#   '.'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['multitude',
#   'film',
#   'twist',
#   'plot',
#   ',',
#   'example',
#   'gone',
#   'girl',
#   ',',
#   'memento',
#   ',',
#   'lot',
#   'film',
#   'm.',
#   'night',
#   'shyamalan',
#   ',',
#   'usual',
#   'suspects',
#   ',',
#   'shutter',
#   'island',
#   ',',
#   'fight',
#   'club',
#   ',',
#   'well',
#   'go',
#   'on',
#   '.'],
#  ['[', 'here', 'list', '100', 'twists', ']', '.'],
#  ['usually',
#   'consists',
#   'plot',
#   'advances',
#   ',',
#   'hidden',
#   'information',
#   'completely',
#   'revealed',
#   'yet',
#   '.'],
#  ['information', 'revealed', ',', 'heighten', 'liking', 'plot', '.'],
#  ["feels'mind",
#   'blowing',
#   "'",
#   ',',
#   'movie',
#   'instantly',
#   'go',
#   'deeper',
#   ',',
#   'suddenly',
#   'complex',
#   'movie',
#   ',',
#   'twist',
#   'ideal',
#   'deep',
#   'analysis',
#   'allegories',
#   '.'],
#  ['adding',
#   'twist',
#   'plot',
#   'make',
#   'everyone',
#   "say'wow",
#   "'",
#   'one',
#   'guy',
#   'say',
#   ':',
#   "'",
#   'i',
#   'knew',
#   'along',
#   "'",
#   '.'],
#  ['think',
#   'analogy',
#   'showing',
#   'people',
#   'like',
#   'much',
#   ',',
#   'abit',
#   'like',
#   'plato',
#   "'s",
#   'cave',
#   'suddenly',
#   'showing',
#   'light',
#   'deeper',
#   'meaning',
#   '.'],
#  ['however',
#   ',',
#   'point',
#   ',',
#   'simple',
#   'cheap',
#   'way',
#   'make',
#   'movie',
#   'much',
#   'smarter',
#   'initially',
#   'was',
#   '.'],
#  ['think',
#   'also',
#   'high',
#   'amount',
#   'plot',
#   'twist',
#   'movie',
#   'imdb',
#   'top',
#   '250',
#   '(',
#   'by',
#   'mean',
#   'standard',
#   ',',
#   'good',
#   'representative',
#   'liked',
#   'movie-goers',
#   ')',
#   '.'],
#  ['adding',
#   'well',
#   'written',
#   'plot',
#   'twist',
#   'make',
#   'movie',
#   'ripe',
#   'people',
#   'laud',
#   'it',
#   ',',
#   'even',
#   'though',
#   'done',
#   'dead',
#   '.'],
#  ['basically',
#   'point',
#   'simple',
#   'way',
#   'make',
#   "movie'smarter",
#   "'",
#   'overdone',
#   'method',
#   "of'blowing",
#   'people',
#   'minds',
#   "'",
#   '.'],
#  ['instantly', 'add', 'point', 'movie-goers', '.'],
#  ['said', 'title', ',', 'point', "non-amusing'plot", 'device', "'", '.'],
#  ['simple', 'way', 'add', 'layer', 'movie', '.'],
#  ['watching',
#   'movie',
#   'always',
#   'seem',
#   'like',
#   'twist',
#   '(',
#   'i',
#   'thought',
#   'gone',
#   'girl',
#   'well',
#   'sincerely',
#   'surprised',
#   'me',
#   ')',
#   'afterwards',
#   'cinema',
#   'rational',
#   "think'hmm",
#   ',',
#   'another',
#   'twistmovie',
#   "'",
#   '.'],
#  ['apart', 'twist', 'nothing', 'really', 'interesting', 'going', 'on', '.'],
#  ['well',
#   'regarded',
#   'movie',
#   'like',
#   'twist',
#   "was'the",
#   'usual',
#   'suspects',
#   "'",
#   '.'],
#  ['cinematography',
#   'acting',
#   'obviously',
#   'well',
#   'done',
#   ',',
#   'looking',
#   'plot',
#   'thought',
#   'impressive',
#   'taking',
#   'away',
#   'twist',
#   '.'],
#  ['probably', 'triggering', 'couple', 'readers', ',', 'sorry', '.'],
#  ['however', 'critique', 'movie', ',', 'example', '.'],
#  ['also',
#   'think',
#   'reason',
#   'm.',
#   'night',
#   'shyamalan',
#   'well',
#   'recieved',
#   'start',
#   'career',
#   'way',
#   'le',
#   'regarded',
#   'time',
#   '.'],
#  ['time', ',', 'surface', 'cheap', "movie'plot", 'device', "'", '.'],
#  ['twice', 'people', 'noticed', 'significantly', '.'],
#  ['(',
#   'i',
#   'sorry',
#   'spelling',
#   'mistakes',
#   ',',
#   'native',
#   'speaker',
#   ')',
#   'hello',
#   ',',
#   'user',
#   'cmv',
#   '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
# ...
#  ['now',
#   ',',
#   'ca',
#   "n't",
#   'say',
#   'friend',
#   'people',
#   'gone',
#   'family',
#   'people',
#   'general',
#   '.'],
#  ['walking',
#   'date',
#   '(',
#   'm',
#   ')',
#   'town',
#   ',',
#   'group',
#   'college',
#   'student',
#   'started',
#   'laughing',
#   'u',
#   'holding',
#   'hands',
#   '.'],
#  ['walking',
#   'by',
#   ',',
#   'kept',
#   'thinking',
#   'way',
#   'could',
#   'get',
#   'stop',
#   'laugh',
#   'us',
#   ',',
#   'else',
#   'gon',
#   'na',
#   'make',
#   'feel',
#   'humiliated',
#   'disgusting',
#   '.'],
#  ['felt', 'like', 'pet', '.'],
#  ['play', 'toy', '.'],
#  ['life', 'humorous', 'people', '.'],
#  ['ca',
#   "n't",
#   'say',
#   'would',
#   'anything',
#   'say',
#   'make',
#   'realize',
#   'normal',
#   'appeal',
#   'sex',
#   '.'],
#  ['i', "'m", 'education', '.'],
#  ['believe',
#   'education',
#   'make',
#   'world',
#   'go',
#   'around',
#   'perfect',
#   'learn',
#   'abd',
#   'understand',
#   'new',
#   'thing',
#   'world',
#   'open',
#   'minded',
#   'everything',
#   '.'],
#  ['however',
#   ',',
#   'see',
#   'group',
#   'people',
#   'act',
#   'ignorantly',
#   ',',
#   'ca',
#   "n't",
#   'help',
#   'clench',
#   'fist',
#   'think',
#   'raising',
#   'hell',
#   'life',
#   '.'],
#  ['people', 'kind', 'take', 'pleasure', 'hurting', 'people', '.'],
#  ['why', '?'],
#  ['want', 'themselves', '.'],
#  ['think', 'they', "'re", 'perfect', 'everyone', 'else', '.'],
#  ['sure', 'hell', 'perfect', '.'],
#  ['resort', 'violence', 'come', 'topic', '.'],
#  ['hear', 'see', 'ignorance', 'made', 'hurt', 'others', ',', 'like', '.'],
#  ['ca',
#   "n't",
#   'help',
#   'feel',
#   'like',
#   'ignorance',
#   'need',
#   'dealt',
#   'punch',
#   'face',
#   '.'],
#  ['nobody', 'deserves', 'got', '.'],
#  ['nobody', 'deserves', 'ignorance', 'others', 'recieve', '.'],
#  ['ignorance',
#   'stem',
#   'close',
#   'mindedness',
#   ',',
#   'something',
#   'world',
#   'need',
#   '.'],
#  ['close', 'minded', ',', 'advanced', 'far', 'have', '.'],
#  ['really', 'need', 'world', '?'],
#  ['necessary', 'survival', '?'],
#  ['believe',
#   'extent',
#   'absolutely',
#   'close',
#   'minded',
#   'person',
#   ',',
#   'there',
#   'equally',
#   'absolutely',
#   'open',
#   'minded',
#   'person',
#   '(',
#   'the',
#   'bell',
#   'curve',
#   ')',
#   '.'],
#  ['deal',
#   'people',
#   'punish',
#   'hurt',
#   'nowhere',
#   'near',
#   'pain',
#   'they',
#   "'ve",
#   'inflicted',
#   'onto',
#   'people',
#   ',',
#   'still',
#   'sending',
#   'message',
#   '.'],
#  ['cmv', 'edit', ':', 'know', 'violence', 'get', 'anywhere', '.'],
#  ['solution',
#   'besides',
#   'time',
#   ',',
#   'education',
#   'ignorng',
#   'people',
#   'remedy',
#   'situation',
#   'directly',
#   '?'],
#  ['people',
#   'developed',
#   'world',
#   'becoming',
#   'obese',
#   ',',
#   'many',
#   'government',
#   'begun',
#   'tax',
#   'various',
#   'food',
#   'deem',
#   'unhealthy',
#   'allegedly',
#   'contributing',
#   'epidemic',
#   '.'],
#  ['pigovian',
#   '(',
#   'no',
#   'pun',
#   'intended',
#   ')',
#   'tax',
#   'kind',
#   'may',
#   'effective',
#   'thing',
#   'like',
#   'alcohol',
#   'tobacco',
#   ',',
#   'believe',
#   'work',
#   'tax',
#   'make',
#   'majority',
#   'price',
#   'product',
#   '.'],
#  ['extra',
#   'ten',
#   'cent',
#   'morning',
#   'gravy',
#   'going',
#   'make',
#   'fatso',
#   'switch',
#   'slimfast',
#   '.'],
#  ['unfortunately',
#   'doubling',
#   'tripling',
#   'price',
#   'junk',
#   'food',
#   'would',
#   'completely',
#   'destroy',
#   'market',
#   'thing',
#   'put',
#   'manufacturer',
#   'business',
#   'almost',
#   'immediately',
#   '.'],
#  ['easy',
#   'untaxed',
#   'alternative',
#   'junk',
#   'food',
#   ',',
#   'unlike',
#   'booze',
#   'cigarettes',
#   '.'],
#  ['granted',
#   'could',
#   'grow',
#   'tobacco',
#   'brew',
#   'beer',
#   ',',
#   'take',
#   'months',
#   ',',
#   'making',
#   'junk',
#   'food',
#   'tax-free',
#   'ingredient',
#   'take',
#   'minutes',
#   '.'],
#  ['plus',
#   'steak',
#   'cost',
#   'bag',
#   'chip',
#   'people',
#   'would',
#   'simply',
#   'become',
#   'obese',
#   'sirloin',
#   'rather',
#   'doritos',
#   '.'],
#  ['raising',
#   'price',
#   'food',
#   'like',
#   'would',
#   'also',
#   'harmful',
#   'poor',
#   ',',
#   'especially',
#   'considering',
#   'junk',
#   'food',
#   'often',
#   'provides',
#   'calorie',
#   'dollar',
#   ',',
#   'thus',
#   'essential',
#   'many',
#   'poor',
#   'people',
#   'meet',
#   'daily',
#   'nutritional',
#   'requirements',
#   '.'],
#  ['say',
#   'want',
#   'diet',
#   'high',
#   'fat',
#   'sugar',
#   ',',
#   'still',
#   'healthier',
#   'starvation',
#   '.'],
#  ['addition',
#   'grossly',
#   'unfair',
#   'punish',
#   'everybody',
#   'obese',
#   'need',
#   'cut',
#   'back',
#   '.'],
#  ['even',
#   'alcohol',
#   'tobacco',
#   'would',
#   'relatively',
#   'harmless',
#   'moderation',
#   ',',
#   'practice',
#   'would',
#   'difficult',
#   'vendor',
#   'tell',
#   'someone',
#   'alcoholic',
#   'chain-smoker',
#   'self-control',
#   '.'],
#  ['hand',
#   ',',
#   'much',
#   'chagrin',
#   ',',
#   'nobody',
#   'ever',
#   'mistaken',
#   'obese',
#   'person',
#   'slim',
#   ',',
#   'matter',
#   'strong',
#   'elastic',
#   'girdle',
#   '.'],
#  ['unfortunately',
#   'system',
#   'implemented',
#   'many',
#   'fatty',
#   'would',
#   'cheat',
#   'skinny',
#   'friend',
#   'relative',
#   'buy',
#   'junk',
#   'food',
#   'them',
#   '.'],
#  ['viable',
#   'solution',
#   'see',
#   'would',
#   'tax',
#   'food',
#   ',',
#   'rather',
#   'pants',
#   ',',
#   'say',
#   '5-10',
#   'per',
#   'inch',
#   'waistline',
#   'larger',
#   'inseam',
#   '.'],
#  ['would', 'ensure', 'fat', 'would', 'pay', 'fat', 'taxes', '.'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['cmv', 'whether', 'believe', 'alien', 'exist', '.'],
#  ['widely',
#   'held',
#   'point',
#   'view',
#   ':',
#   'think',
#   'alien',
#   'life',
#   'exists',
#   'elsewhere',
#   'universe',
#   ',',
#   'crazy',
#   '.'],
#  ['understand',
#   'view',
#   'come',
#   'from',
#   ';',
#   '[',
#   'universe',
#   'unimaginably',
#   'huge',
#   ']',
#   'filled',
#   '[',
#   'galaxies',
#   ']',
#   ',',
#   'therefore',
#   'stars',
#   ',',
#   'therefore',
#   '[',
#   'planets',
#   ']',
#   ',',
#   'simply',
#   'must',
#   'life',
#   'there',
#   '.'],
#  ['view',
#   'approach',
#   'fundamentally',
#   'unscientific',
#   'held',
#   'based',
#   'probability',
#   'actual',
#   'scientific',
#   'evidence',
#   '.'],
#  ['background',
#   ':',
#   'physic',
#   'astronomy',
#   'teacher',
#   ',',
#   'teach',
#   'subject',
#   'depth',
#   'every',
#   'year',
#   '.'],
#  ['think', 'research', 'often', '.'],
#  ['i',
#   "'m",
#   'well',
#   'acquainted',
#   '[',
#   'drake',
#   'equation',
#   ']',
#   ',',
#   '[',
#   'fermi',
#   'paradox',
#   ']',
#   '[',
#   'its',
#   'many',
#   'possible',
#   'solutions',
#   ']',
#   ',',
#   '[',
#   'great',
#   'filter',
#   ']',
#   ',',
#   'debate',
#   'alien',
#   'life',
#   'general',
#   '.'],
#  ['belief',
#   'matter',
#   'used',
#   'strongly',
#   "'of",
#   'course',
#   'alien',
#   'exist',
#   'there',
#   "'",
#   'side',
#   ',',
#   'thought',
#   'distance',
#   'vast',
#   'u',
#   'ever',
#   'observe',
#   'them',
#   '.'],
#  ['however',
#   ',',
#   'opinion',
#   'strongly',
#   'shifted',
#   'book',
#   'alone',
#   'universe',
#   '[',
#   'john',
#   'gribbin',
#   ']',
#   ',',
#   'think',
#   'great',
#   'profusion',
#   'life',
#   'earth',
#   'rare',
#   'alone',
#   'universe',
#   '.'],
#  ['get',
#   'wrong',
#   ',',
#   'i',
#   "'m",
#   'completely',
#   'open',
#   'idea',
#   'alien',
#   'existing',
#   '.'],
#  ['kind', 'hope', 'do', ',', 'long', 'destroy', 'u', 'all', '!'],
#  ['get',
#   'kind',
#   'scientific',
#   'evidence',
#   'exist',
#   '-',
#   'organized',
#   'signal',
#   ',',
#   'clear',
#   'alien-made',
#   'trace',
#   'element',
#   'planet',
#   "'s",
#   'spectroscopy',
#   ',',
#   'anything',
#   'measurable',
#   '-',
#   'think',
#   'correct',
#   'scientific',
#   'approach',
#   'exist',
#   '.'],
#  ['cmv', '.'],
#  ['edit', '1', ':', 'good', 'thought', 'here', ',', 'thanks', '.'],
#  ['also', ',', 'incorrect', 'assumption', 'i', "'m", 'saying', '.'],
#  ['probability',
#   'course',
#   'useful',
#   'scientific',
#   'tool',
#   ',',
#   'key',
#   'understanding',
#   'quantum',
#   'mechanics',
#   '.'],
#  ['guess',
#   'drake',
#   'equation',
#   'boil',
#   'probability',
#   'based',
#   'data',
#   ',',
#   'quite',
#   'different',
#   'data-based',
#   'probability',
#   'qm',
#   '.'],
#  ['compelling',
#   'argument',
#   'i',
#   "'ve",
#   'read',
#   'know',
#   'life',
#   'happened',
#   'universe',
#   'us',
#   ',',
#   'could',
#   'happen',
#   'again',
#   '.'],
#  ['physical',
#   'law',
#   'symmetry',
#   'point',
#   'idea',
#   'unique',
#   'event',
#   'universe',
#   '.'],
#  ['i',
#   "'m",
#   'sure',
#   'agree',
#   'that',
#   ',',
#   'given',
#   'something',
#   'think',
#   'about',
#   '.'],
#  ['crux', 'argument', 'come', 'abiogenesis', ',', 'life', 'non-life', '.'],
#  ['easy', 'hard', '?'],
#  ['could', 'happened', 'once', '?'],
#  ['alone',
#   'universe',
#   'argues',
#   'lot',
#   'thing',
#   'go',
#   'right',
#   'u',
#   'exist',
#   '.'],
#  ['call',
#   "things'drake",
#   "'s",
#   'denominator',
#   "'",
#   'class',
#   'score',
#   'thing',
#   'went',
#   'right',
#   'u',
#   'might',
#   'kill',
#   'huge',
#   'total',
#   'galaxies',
#   ',',
#   'stars',
#   ',',
#   'planets',
#   '.'],
#  ['edit', '2', ':', 'delta', 'awarded', ',', 'thanks', 'thoughts', '.'],
#  ['realized',
#   'even',
#   'single',
#   'data',
#   'point',
#   'life',
#   ',',
#   'life',
#   'earth',
#   ',',
#   'make',
#   'possible',
#   'life',
#   'exist',
#   'there',
#   '.'],
#  ['evidence', 'yet', ',', 'unscientific', 'imagine', 'exists', '.'],
#  ['still',
#   'think',
#   'life',
#   'exceedingly',
#   'rare',
#   'there',
#   ',',
#   'perhaps',
#   'we',
#   "'re",
#   'alone',
#   '.'],
#  ['strange', 'thing', 'we', "'ll", 'probably', 'never', 'know', '.'],
#  ['story',
#   '[',
#   'vlad',
#   'astrophysicist',
#   ']',
#   'closer',
#   'main',
#   'view',
#   'alien',
#   'general',
#   'civilization',
#   'pop',
#   'existence',
#   'time',
#   'all',
#   ',',
#   'never',
#   'chance',
#   'reach',
#   'across',
#   'space',
#   'communicate',
#   '.'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['me',
#   ',',
#   'human',
#   "'s",
#   'well-being',
#   'enjoyment',
#   'always',
#   'trump',
#   'animal',
#   "'s",
#   '.'],
#  ['morally',
#   'justify',
#   'continuing',
#   'eat',
#   'meat',
#   'despite',
#   'rampant',
#   'abuse',
#   'animal',
#   'despite',
#   'specific',
#   'human',
#   'need',
#   'continue',
#   'eat',
#   'meat',
#   'much',
#   'western',
#   'world',
#   '.'],
#  ['thing',
#   ';',
#   'time',
#   ',',
#   'hunting',
#   'need',
#   'to',
#   ',',
#   'we',
#   "'re",
#   'hunting',
#   'want',
#   'to',
#   '.'],
#  ['selective',
#   'outrage',
#   'cecil',
#   'tell',
#   'we',
#   ',',
#   'society',
#   ',',
#   'simply',
#   'unified',
#   'logic',
#   'towards',
#   'supposed',
#   'treat',
#   'animal',
#   'instead',
#   'attach',
#   'moral',
#   'view',
#   'animal',
#   'treatment',
#   'whatever',
#   'culture',
#   'find',
#   'fashionable',
#   '.'],
#  ['walter',
#   'james',
#   'palmer',
#   'potentially',
#   'going',
#   'face',
#   'criminal',
#   'charge',
#   'tyson',
#   'perdue',
#   'make',
#   'industry',
#   'treatment',
#   'animals',
#   '.'],
#  ['little', 'difference', '.'],
#  ['edit', ':', 'opinion', 'changed', '.'],
#  ['cecil',
#   "'s",
#   'existence',
#   'national',
#   'treasure',
#   'zimbabwe',
#   'enough',
#   'justify',
#   'selective',
#   'outrage',
#   '.'],
#  ['moreover',
#   ',',
#   'cecil',
#   "'s",
#   'death',
#   'specifically',
#   'highlight',
#   'issue',
#   'inherent',
#   'illegal',
#   'poaching',
#   '.'],
#  ['hello', ',', 'user', 'cmv', '!'],
#  ['footnote', 'moderators', '.'],
#  ['we', "'d", 'like', 'remind', 'couple', 'things', '.'],
#  ['firstly', ',', 'please', 'remember', '[', 'read', 'rules', ']', '.'],
#  ['see',
#   'comment',
#   'broken',
#   'one',
#   ',',
#   'effective',
#   'report',
#   'downvote',
#   'it',
#   '.'],
#  ['speaking', 'which', ',', '[', 'downvotes', 'change', 'views', ']', '!'],
#  ['thinking',
#   'submitting',
#   'cmv',
#   'yourself',
#   ',',
#   'please',
#   'look',
#   '[',
#   'popular',
#   'topic',
#   'wiki',
#   ']',
#   'first',
#   '.'],
#  ['question', 'concerns', '?'],
#  ['feel', 'free', '[', 'message', 'us', ']', '.'],
#  ['happy', 'cmving', '!'],
#  ['generally',
#   'speaking',
#   ',',
#   'two',
#   'side',
#   '``',
#   'fat',
#   'debate',
#   "''",
#   ':',
#   'fat',
#   'acceptance',
#   'movement',
#   '(',
#   'healthy',
#   'every',
#   'size',
#   ',',
#   'etc',
#   '.',
#   ')'],
#  ['fat',
#   'shamers',
#   '(',
#   'who',
#   'cajole',
#   'fat',
#   'people',
#   'losing',
#   'weight',
#   ',',
#   'either',
#   'benign',
#   'malicious',
#   'intentions',
#   '.'],
#  ['first', 'all', ',', 'buy', 'haes', '.'],
#  ['believe', 'anyone', 'size', 'healthier', 'size', '.'],
#  ['start',
#   'jogging',
#   'week',
#   ',',
#   'probably',
#   'lose',
#   'weight',
#   ',',
#   'i',
#   "'ll",
#   'teeny-tiny',
#   'bit',
#   'healthier',
#   'that',
#   "'s",
#   'good',
#   '.'],
#  ['secondly', ',', 'bmi', 'overall', 'population', 'indicator', '.'],
#  ['course',
#   'given',
#   'people',
#   'overweight',
#   'healthier',
#   'given',
#   'people',
#   'within',
#   'normal',
#   'range',
#   '.'],
#  ['go',
#   'given',
#   'people',
#   'underweight',
#   'v',
#   'people',
#   'normal',
#   'range',
#   '.'],
#  ['however',
#   ',',
#   'would',
#   'state',
#   'general',
#   ',',
#   'slide',
#   'scale',
#   '22.5',
#   'either',
#   'direction',
#   ',',
#   'getting',
#   'optimal',
#   '.'],
#  ['however',
#   ',',
#   'wherever',
#   'people',
#   'lie',
#   'scale',
#   '-',
#   'underweight',
#   '-',
#   'optimal',
#   '-',
#   'fat',
#   'none',
#   'fucking',
#   'business',
#   'whatsoever',
#   '.'],
#  ['stakeholder',
#   'stranger',
#   "'s",
#   'health',
#   'people',
#   'would',
#   'well',
#   'keep',
#   'mouth',
#   'shut',
#   'people',
#   "'s",
#   'appearance',
#   '.'],
#  ['stakeholder',
#   'health',
#   '(',
#   'and',
#   'exclusively',
#   'limited',
#   'loved',
#   'one',
#   'person',
#   "'s",
#   'healthcare',
#   'practitioners',
#   ')',
#   'maybe',
#   'get',
#   'say',
#   'something',
#   '.'],
#  ['maybe', '.'],
#  ['best', 'analogy', 'smoking', '.'],
#  ['smoke',
#   'slightly',
#   'overweight',
#   '(',
#   '10lb',
#   ')',
#   'certainly',
#   'smoking',
#   'detrimental',
#   'health',
#   'extra',
#   'pounds',
#   '.'],
#  ['know', 'smoking', 'bad', '-', 'i', "'m", 'idiot', '.'],
#  ['view',
#   'haes',
#   'bit',
#   'like',
#   '``',
#   'healthy',
#   'matter',
#   'much',
#   'smoke',
#   '.',
#   "''"],
#  ['true', ',', 'may', 'even', 'damaging', '.'],
#  ['hand',
#   ',',
#   'encouraging',
#   'hardened',
#   'smoker',
#   'run',
#   'around',
#   'despite',
#   'smoker',
#   'ai',
#   "n't",
#   'bad',
#   'thing',
#   '.'],
#  ['attack', 'campaign', ',', 'must', ',', 'leave', 'people', 'alone', '.'],
#  ['matter', 'many', 'people', 'tell', 'smoking', 'bad', 'me', '.'],
#  ['statement',
#   'uninvited',
#   ',',
#   'irritating',
#   'precisely',
#   'nothing',
#   'change',
#   'habits',
#   '.'],
#  ['may', 'even', 'reinforce', 'them', '.'],
#  ['none', 'business', 'smoke', '.'],
#  ['know',
#   'eating',
#   'pizza',
#   'one',
#   'vegan',
#   'health',
#   'nut',
#   'friend',
#   'tell',
#   'pepperoni',
#   'full',
#   'carcinogen',
#   'dairy',
#   'cause',
#   'kind',
#   'damage',
#   'you',
#   '?'],
#  ['that', ',', 'best', 'fat', 'shamers', 'come', 'like', '.'],
#  ['i',
#   "'m",
#   'saying',
#   'public',
#   'health',
#   'campaign',
#   '(',
#   'much',
#   'like',
#   'anti-smoking',
#   'campaigns',
#   ')',
#   ',',
#   'personally',
#   'never',
#   'say',
#   'damn',
#   'thing',
#   'stranger',
#   "'s",
#   'weight',
#   ',',
#   'ever',
#   '.'],
#  ['edit', ':', 'good', 'discussion', ',', 'guys', '.'],
#  ['i',
#   "'m",
#   'going',
#   'delta',
#   'spree',
#   'now',
#   ',',
#   'uthereoncewasaman',
#   'put',
#   'it',
#   ':',
#   '``',
#   'ops',
#   'view',
#   '``',
#   'others',
#   "'",
#   'weight',
#   'none',
#   'business',
#   ',',
#   "''",
#   '``',
#   'you',
#   'shame',
#   'people',
#   'overweight',
#   '.',
#   "''"],
#  ['annoyingly', 'correct', 'phrased', 'it', '.'],
#  ...]

# %%
model = Word2Vec(sentences=X_sents, vector_size=100, window=5, min_count=1, workers=4)
model.save("word2vec.model")
word_vectors = model.wv
word_vectors.save("word2vec.wordvectors") # Store the words and their trained embeddings
del model

# %% [markdown]
# ## Training a classifier

# %%
def document_vector(doc, wv):
    """Create document vectors by averaging word vectors."""
    words = word_tokenize(doc)
    word_vectors = np.array([wv[word] for word in words if word in wv])

    if len(word_vectors) == 0:
        return np.zeros(wv.vector_size)
    return np.mean(word_vectors, axis=0)

# %%
X = df["text_preprocess"]
y = df["label"]

wv = KeyedVectors.load("word2vec.wordvectors", mmap='r')
X = np.array([document_vector(doc, wv) for doc in X])

X_train, X_test, y_train, y_test = train_test_split(X, df.label, test_size=0.2, random_state=42)
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train)
print(f"Features dimension: {X_train.shape}")
# Out:
# Features dimension: (255256, 100)

# %%
classifier = make_pipeline(LogisticRegression(random_state=42, class_weight='balanced', penalty='l2',max_iter=1000))

# %%
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.71      0.77     45073
#            1       0.50      0.69      0.58     18742
#
#     accuracy                           0.70     63815
#    macro avg       0.67      0.70      0.68     63815
# weighted avg       0.74      0.70      0.72     63815

# %% [markdown]
# ## Plot confusion matrix

# %%
cm = confusion_matrix(y_test, y_pred, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=[0,1])
disp.plot()
plt.show()

# %% [markdown]
# ## Optimize hyperparameters using Grid Search

# %%
model = make_pipeline(LogisticRegression(random_state=42, class_weight='balanced'))

param_grid = {
    'logisticregression__C': [0.001, 0.01, 0.1, 1, 10, 100],
}

grid_search = GridSearchCV(model, param_grid, cv=5, scoring='f1_macro', verbose=1, n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)

best_model = grid_search.best_estimator_
test_score = best_model.score(X_test, y_test)
print("Test set score:", test_score)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'logisticregression__C': 1}
# Best cross-validation score: 0.6764126520488701
# Test set score: 0.7048342866097312
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
